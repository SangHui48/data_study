# %% [markdown]
# # 합성곱 신경망의 시각화
# #### 핵심 키워드: 가중치 시각화, 특성 맵 시각화, 함수형 API

# %%
from tensorflow import keras
model = keras.models.load_model('best-cnn-model.h5')

# %%
model.layers
# Out:
# [<keras.layers.convolutional.conv2d.Conv2D at 0x15232332670>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x15232332580>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x15232531340>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1523253a730>,
#  <keras.layers.reshaping.flatten.Flatten at 0x15232541a00>,
#  <keras.layers.core.dense.Dense at 0x15232549910>,
#  <keras.layers.regularization.dropout.Dropout at 0x152325496a0>,
#  <keras.layers.core.dense.Dense at 0x1523276ec70>]

# %%
conv = model.layers[0]
print(conv.weights[0].shape, conv.weights[1].shape)
# Out:
# (3, 3, 1, 32) (32,)

# %%
conv_weights = conv.weights[0].numpy()
print(conv_weights.mean(), conv_weights.std())
# Out:
# -0.013545012 0.23138252

# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import matplotlib.pyplot as plt

plt.hist(conv_weights.reshape(-1, 1))
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 16, figsize=(15, 2))
for i in range(2):
    for j in range(16):
        axs[i, j].imshow(conv_weights[:,:,0,i*16 + j], vmin=-0.5, vmax=0.5)
        axs[i, j].axis('off')
plt.show()

# %%
no_training_model = keras.Sequential()
no_training_model.add(keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding='same', input_shape=(28,28,1)))

# %%
no_training_conv = no_training_model.layers[0]
print(no_training_conv.weights[0].shape)
# Out:
# (3, 3, 1, 32)

# %%
no_training_weights = no_training_conv.weights[0].numpy()
print(no_training_weights.mean(), no_training_weights.std())
# Out:
# -0.00951526 0.083051264

# %%
import matplotlib.pyplot as plt

plt.hist(no_training_weights.reshape(-1, 1))
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 16, figsize=(15, 2))
for i in range(2):
    for j in range(16):
        axs[i, j].imshow(no_training_weights[:,:,0,i*16 + j], vmin=-0.5, vmax=0.5)
        axs[i, j].axis('off')
plt.show()

# %%
print(model.input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='conv2d_input'), name='conv2d_input', description="created by layer 'conv2d_input'")

# %%
conv_acti = keras.Model(model.input, model.layers[0].output)

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
plt.imshow(train_input[0], cmap='gray_r')
plt.show()

# %%
inputs = train_input[0].reshape(-1, 28, 28, 1) / 255.0
feature_maps = conv_acti.predict(inputs)
# Out:
# 1/1 [==============================] - 0s 173ms/step

# %%
print(feature_maps.shape)
# Out:
# (1, 28, 28, 32)

# %%
fig, axs = plt.subplots(4, 8, figsize=(15, 8))
for i in range(4):
    for j in range(8):
        axs[i, j].imshow(feature_maps[0, :, :, i*8 + j])
        axs[i, j].axis('off')
plt.show()

# %%
conv2_acti = keras.Model(model.input, model.layers[2].output)

# %%
inputs = train_input[0:1].reshape(-1, 28, 28, 1) / 255.0
feature_maps = conv2_acti.predict(inputs)
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
print(feature_maps.shape)
# Out:
# (1, 14, 14, 64)

# %%
fig, axs = plt.subplots(8, 8, figsize=(12, 12))
for i in range(8):
    for j in range(8):
        axs[i, j].imshow(feature_maps[0,:,:,i*8 + j])
        axs[i, j].axis('off')
plt.show()

# %% [markdown]
# * **가중치 시각화** 합성곱층의 가중치를 이미지로 출력하는 것을 말한다. 합성곱 신경망은 주로 이미지를 다루기 때문에 가중치가 시각적인 패턴을 학습하는지 알아볼 수 있다.
# * **특성 맵 시각화**는 합성곱 층의 활성화 출력을 이미지로 그리는 것을 말한다. 가중치 시각화와 함께 비교하여 각 필터가 이미지의 어느 부분을 활성화시키는지 확인할 수 있다.
# * **함수형 API**는 케라스에서 신경망 모델을 만드는 방법 중 하나이다. Model 클래스에 모델의 입력과 출력을 지정한다. 전형적으로 입력은 Input() 함수를 사용하여 정의하고 출력은 마지막 층의 출력으로 정의한다.
