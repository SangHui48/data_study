# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Hannanum

# %%
national_anthem = """
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
남산 위에 저 소나무 철갑을 두른 듯
바람 서리 불변함은 우리 기상일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
가을 하늘 공활한데 높고 구름 없이
밝은 달은 우리 가슴 일편단심일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
이 기상과 이 맘으로 충성을 다하여
괴로우나 즐거우나 나라 사랑하세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
"""

# %%
hananum = Hannanum()
nouns = hananum.nouns(national_anthem)

# %%
print(nouns[:10])
# Out:
# ['동해물', '백두산', '하느님', '보우하사', '우리나라', '무궁화', '삼천리', '화', '강산', '사람']

# %%
counter = Counter(nouns)
print(counter)
# Out:
# Counter({'무궁화': 4, '삼천리': 4, '화': 4, '강산': 4, '사람': 4, '대한': 4, '길': 4, '보전하세': 4, '우리': 2, '동해물': 1, '백두산': 1, '하느님': 1, '보우하사': 1, '우리나라': 1, '남산': 1, '위': 1, '소나무': 1, '철갑': 1, '듯': 1, '불변': 1, '기상일세': 1, '하늘': 1, '공활한데': 1, '구름': 1, '달': 1, '가슴': 1, '일편단심일세': 1, '기상': 1, '충성': 1, '사랑하세': 1})

# %%
wordcloud = WordCloud(
    font_path='C:\Windows\Fonts\malgun.TTF',
    background_color='white',
    width=1000,
    height=1000
)
img = wordcloud.generate_from_frequencies(counter)
plt.imshow(img)

# %%
import requests
from bs4 import BeautifulSoup

user_agent = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"}

import time
questions = []

for i in range(1, 6):
    res = requests.get(f'https://hashcode.co.kr/?page={i}', {"User-Agent": user_agent})
    soup = BeautifulSoup(res.text, 'html.parser')
    parsed_datas = soup.find_all('li', 'question-list-item')
    for data in parsed_datas:
        questions.append(data.h4.text.strip())
    time.sleep(0.5)
            
print(questions)
# Out:
# ['Situs IDN Poker Online Resmi Terpercaya Indonesia', '자바 객체선언 오류 질문입니다!', '파이썬 간단한 코드 질문', '[ASP, VB.NET] API 제공 중인데 json 값 앞에 태그가 붙은 이유가 뭘까요?', "'''로 주석으로 만들었는데 왜 주석을 지우지 않으면 유니코드오류가 왜 나는지 모르겠어여", '#define 상수 선언떄', '우분투 vmware 가상머신 오류', '파이썬 멀티스레딩 질문', '파이썬 엑셀 파일 읽기', '머쓱이 스탬프 할때 답보기요', 'BFS를 사용해도 무관한지 궁금합니다!', 'C# 백준 25206 문제 뭐가 문제인지 확인시켜줄 고수분', 'python 제너레이터화', '리액트 쿼리에서 useQuery를 어떻게 사용해야하나요', 'html/javascript 로 node.js통해서 아두이노 통신관련', 'Binary search tree', 'Python 정규표현식을 사용한 패턴 추출', "code: 'MODULE_NOT_FOUND' 좀 도와주세요", '파이썬 데이터베이스 저장할때 다른방법없을까요?', '코딩테스트 첫번째 폰켓몬 문제 왜 맞는건가요?', '좋아요 한 문제만 따로 볼 수 있나요?', '멀티프로세싱 프로그램 실행시 수십개의 프로그램이 실행됩니다.', 'c언어 왜 소수점을 넣어야 결과가 나오나', 'HTML 전혀 모르는데요', 'QR코드만 이용해서 앱 개발을 하면 많이 힘들까요?', '(생초보) 파이썬 *매개변수의 개수', '로지스틱 회귀', '프로그래머스 코딩테스트 2단계 구명보트에서', 'Java 개인 연습 중 배열에서 오류가 났는데 해결 방법을 모르겠습니다.', '파이썬 csv 파일을 불러와 구분하는 방법에 대해 질문 드립니다', "다음의 xarray를 어떻게 'time' series로 변형할 수 있는지 여쭈어봅니다.", "'xlsx' file을 'nc' format으로 변환 후 저장하는 과정에서 계속 에러가 뜹니다..", 'dayArray[dayOfWeek-1]  이건 어떻게 해석하나요?', '파이썬 클래스 객체 생성에 관한 질문', 'HashMap에서 equals 재정의할때 들어가는 Object가 뭔지좀 가르쳐주세요', '파이썬 beautifulsoup 텍스트만 출력하기', 'spy++, inspect가 특정 프로그램의 child windows를 불러오지 못하는 거 같습니다', '[python질문] i for i in range를 처음보는데 질문있습니다..', '파이썬 웹크롤링 selenium 공부 중인데 계속 타입에러가 떠서 왜 오류가 이렇게 뜨는지 알  수 있을까요ㅠㅠ', 'c언어 코딩테스트 level0 문제 어디가 문제 있나요?', '한달 째 고민중인 cpp "char" 1byte send/receive 코드 질문 드립니다..ㅠㅠ', '스킬 체크 테스트 Level.2 문제 2 Java 무한루프 문의드립니다.', '자바스크립트 저장된 파일 제목으로 날짜 뽑는법 질문드립니다.', '자바스크립트 세션 스토리지에 slider 발류 저장법', 'Regex로 특정 단어부터 empty lines까지 찾는 법', 'TimSort의 단점이 뭘까요?', '파이썬 BeautifulSoup4 웹크롤링 관련 질문', '자바스크립트 분수의 덧셈 질문입니다. 뭐가 문제인지 모르겠어요', '맥에서 터미널을 킬때 이런 문구가 나옵니다', '파이썬3 2차원배열 입력하기', 'MFC 마우스 이벤트 처리 관련 질문입니다.', '자바스크립트 질문있습니다.', 'python의 os 모듈의 listdir함수에 대해 질문있습니다', "AttributeError at /admin/r/31/4/ 'NoneType' object has no attribute 'startswith'", 'id.length==0 || id=="" 둘다 같은의미아닌가요?', '자바 iterator 질문이요', '파이썬 Django 질문이욧!!!', 'javascript 의 재귀함수 문제', 'c++ class 동적할당 배열 생성자', '스프링 배치 writer 질문', 'C++ STRCAT 구현부분 질문', '파이썬 모듈 설치 하기', '[python3] Lv.1 신고 결과 받기 / 접근 방식 및 딕셔너리 값 관련 문제해결', '동적배열을 이렇게 선언하면 안되는 이유가 있나요?', 'qt 디자이너 사용해서 프린터와 pdf 저장하기 작성중입니다. 출력시 에러가 발생됩니다.메인 윈도우 창 전체를 프린터 및 pdf로 저장하고 싶습니다.', 'Q&A 게시판 내 작성글 보기', '서블릿 response관련 기초적인 질문할께요ㅠ', '[코틀린] private 질문', 'live server 에서는 사진이 나오는데 Netlify로 사이트를 만들면 거기서는 사진이 안나와요', '자바 코드 관련하여 질문드립니다', '파이썬으로 서로 다른 두 데이터를 매칭하려 하는데 어떤 방법을 이용해야할지 좋을지 모르겠어요', '영상을 프레임별 이미지로 변환', 'scanf_s와 switch-case문 오류', '라즈베리파이에서 사진 캡쳐 후 저장하는 코드를 짰는데 넘버링을 하고 싶습니다.', 'hide(), show() 가 동기적으로 작동하지 않는데 문제점을 모르겠습니다.', '[VB.NET] POST 방식의 HTTPS 통신 시 에러 문제점', '자료구조 다항식의 덧셈을 자바로 바꾸는 문제. delTerm 같은 함수들 활용법', 'c언어 간단한 문제 질문 儆儆儆儆儆', '아코디언 갤러리를 구현하려고 합니다.', '파이썬 openpyxl 값 좌표 찾는 방법', 'for문을 이용한 json 배열 배치하는 테이블 생성', '판다스 read_excel() 소수점 질문', 'c언어로 마방진 짜는 코드 질문이요', '파이썬 장고(django) 프레임웍 환경에서 자동 로그인 구현하는 방법?', '파이썬 타이머 버튼이 눌렸을 때 시간이 멈추도록', '고수님들 파이썬 엑셀파일 만드는 코드좀 부탁드립니다', 'sql 쿼리 : 특정 카테고리 직전 및 직후 구매한 카테고리', 'overfitting 및 예측 data augmentation', '[판다스] 원천 데이터 프레임의 <>안의 문자만 뽑아 새로운 데이터 프레임 생성', '파이선 체크박스 저장 & 불러오기 질문', '파이썬 버블정렬구현', 'dijkstra 최단경로', '파이썬 이진탐색트리', '[파이썬] 판다스 중복 컬럼 찾기', '과제요청 삭제 코딩 왕초보 입니다.... for문과 인덱싱을 활용한 딕셔너리 출력', 'python -m pip install pyautogui 안되는데 이거 왜 그런건가요.', 'linearmodels install 질문', '컴파일 후 에러 발생', 'pygame 딜레이', 'c언어 파일 출력시 儆儆이러한 문자가 뜨는 이유가 뭔가요?', '리눅스 아니면 아이텀2에서 fxml파일을 만들려고 하는데', 'html class 선언 코드 질문', '터미널 alias 등록', '파이썬 len(str([2,4])) 이 왜 6인가요?', 'folium marker끼리 연결', '자바 랜덤으로 1~6사이의 난수를 뽑는데 2,3,6만 뽑고싶습니다. 이럴땐 어떻게 코딩하나요?', '파이선 데이터 저장 / 불러오기', 'c언어 질문드립니다.', 'Wamp 설치오류 도와주세요 ㅜ', 'Location values cannot contain NaNs.', '(심사 중)이라는 메시지는 어떤 절차가 있다는 걸까요?', 'PG결제 연동시 발생하는 보안이슈 문제질문드립니다.', '입력한 위도와 경도와 csv 파일 내에 있는 위도와 경도 중 가장 가까운 위치 값 찾기', '연결리스트 동적할당 알려주세요', '100일 뒤 기념일 프로그램 코드좀 알려주세요 ㅠㅠ-ㅠ', '영어단어 추출관련 코드 수정 문의', 'CefSharp에서 WebRTC 사용 시 발생하는 문제', 'colab list안에 있는 요소 옮기기', 'bow_vect = vect.fit_transform 부분 오류가 나서 질문드립니다.', '파이썬 BoW 벡터 진행 중 오류가 나서 질문 드립니다.', 'ejs에서 실시간으로 db의 데이터를 가져오는 방법이 있을까요??', '254개 - 248개 매칭 알고르짐에 관한 의견 ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Hannanum

# %%
words = []
hananum = Hannanum()

for question in questions:
    nouns = hananum.nouns(question)
    words += nouns
    
print(len(words))
# Out:
# 1017

# %%
counter = Counter(words)

# %%
wordcloud = WordCloud(
    font_path='C:\Windows\Fonts\malgun.TTF',
    background_color='white',
    width=1000,
    height=1000
)
img = wordcloud.generate_from_frequencies(counter)
plt.imshow(img)
