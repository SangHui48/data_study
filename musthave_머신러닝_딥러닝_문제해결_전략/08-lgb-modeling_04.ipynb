# %% [markdown]
# - [안전 운전자 예측 경진대회 링크](https://www.kaggle.com/c/porto-seguro-safe-driver-prediction)
# - [모델링 코드 참고 링크](https://www.kaggle.com/xiaozhouwang/2nd-place-lightgbm-solution)

# %% [markdown]
# ## 8.4 성능개선1: LightGBM 모델

# %%
# %config Completer.use_jedi = False

import pandas as pd

data_path = '/kaggle/input/porto-seguro-safe-driver-prediction/'

train = pd.read_csv(data_path + 'train.csv', index_col='id')
test = pd.read_csv(data_path + 'test.csv', index_col='id')
submission = pd.read_csv(data_path + 'sample_submission.csv', index_col='id')

# %% [markdown]
# ### 8.4.1 피처 엔지니어링

# %% [markdown]
# * 데이터 합치기

# %%
all_data = pd.concat([train, test], ignore_index=True)
all_data = all_data.drop('target',axis=1)

all_features = all_data.columns

# %% [markdown]
# * 명목형 피처 원-핫 인코딩

# %%
from sklearn.preprocessing import OneHotEncoder

cat_features = [feature for feature in all_features if 'cat' in feature]

onehot_encoder = OneHotEncoder()
encoded_cat_matrix = onehot_encoder.fit_transform(all_data[cat_features])

# %% [markdown]
# * 파생 피처 추가

# %%
# 데이터 하나당 결측값 개수를 파생 피처로 추가
all_data['num_missing'] = (all_data == -1).sum(axis=1)

# %%
# 명목형 피처, calc 분류의 피처를 제외한 피처
remaining_features = [feature for feature in all_features if('cat' not in feature and 'calc' not in feature)]

# num_missing을 remaining_features에 추가
remaining_features.append('num_missing')

# %%
# 분류가 ind인 피처
ind_features = [feature for feature in all_features if 'ind' in feature]

is_first_feature = True
for ind_feature in ind_features:
    if is_first_feature:
        all_data['mix_ind'] = all_data[ind_feature].astype(str) + '_'
        is_first_feature = False
    else:
        all_data['mix_ind'] += all_data[ind_feature].astype(str) + '_'

# %%
all_data['mix_ind']
# Out:
# 0          2_2_5_1_0_0_1_0_0_0_0_0_0_0_11_0_1_0_
# 1           1_1_7_0_0_0_0_1_0_0_0_0_0_0_3_0_0_1_
# 2          5_4_9_1_0_0_0_1_0_0_0_0_0_0_12_1_0_0_
# 3           0_1_2_0_0_1_0_0_0_0_0_0_0_0_8_1_0_0_
# 4           0_2_0_1_0_1_0_0_0_0_0_0_0_0_9_1_0_0_
#                            ...
# 1488023     0_1_6_0_0_0_1_0_0_0_0_0_0_0_2_0_0_1_
# 1488024    5_3_5_1_0_0_0_1_0_0_0_0_0_0_11_1_0_0_
# 1488025     0_1_5_0_0_1_0_0_0_0_0_0_0_0_5_0_0_1_
# 1488026    6_1_5_1_0_0_0_0_1_0_0_0_0_0_13_1_0_0_
# 1488027    7_1_4_1_0_0_0_0_1_0_0_0_0_0_12_1_0_0_
# Name: mix_ind, Length: 1488028, dtype: object

# %%
all_data['ps_ind_02_cat'].value_counts()
# Out:
#  1    1079327
#  2     309747
#  3      70172
#  4      28259
# -1        523
# Name: ps_ind_02_cat, dtype: int64

# %%
all_data['ps_ind_02_cat'].value_counts().to_dict()
# Out:
# {1: 1079327, 2: 309747, 3: 70172, 4: 28259, -1: 523}

# %%
cat_count_features = []
for feature in cat_features+['mix_ind']:
    val_counts_dict = all_data[feature].value_counts().to_dict()
    all_data[f'{feature}_count'] = all_data[feature].apply(lambda x: val_counts_dict[x])
    cat_count_features.append(f'{feature}_count')

# %%
cat_count_features
# Out:
# ['ps_ind_02_cat_count',
#  'ps_ind_04_cat_count',
#  'ps_ind_05_cat_count',
#  'ps_car_01_cat_count',
#  'ps_car_02_cat_count',
#  'ps_car_03_cat_count',
#  'ps_car_04_cat_count',
#  'ps_car_05_cat_count',
#  'ps_car_06_cat_count',
#  'ps_car_07_cat_count',
#  'ps_car_08_cat_count',
#  'ps_car_09_cat_count',
#  'ps_car_10_cat_count',
#  'ps_car_11_cat_count',
#  'mix_ind_count']

# %% [markdown]
# * 필요 없는 피처 제거

# %%
from scipy import sparse

# 필요 없는 피처들
drop_features = ['ps_ind_14', 'ps_ind_10_bin', 'ps_ind_11_bin', 'ps_ind_12_bin', 'ps_ind_13_bin',
                 'ps_car_14']

all_data_remaining = all_data[remaining_features + cat_count_features].drop(drop_features, axis=1)

# 데이터 합치기
all_data_sprs = sparse.hstack([sparse.csr_matrix(all_data_remaining), encoded_cat_matrix], format='csr')

# %% [markdown]
# * 명목형 피처에 원-핫 인코딩을 적용했다.
# * 데이터 하나당 가지고 있는 결측값 개수를 새로운 피처로 만들었다.
# * 모든 ind 피처 값을 연결해서 새로운 명목형 피처를 만들었다.
# * 명목형 피처의 고윳값별 개수를 새로운 피처로 만들었다.
# * 필요 없는 피처를 제거했다.

# %% [markdown]
# * 데이터 나누기

# %%
num_train= len(train)

X = all_data_sprs[:num_train]
X_test = all_data_sprs[num_train:]

y = train['target'].values

# %%
import numpy as np

def eval_gini(y_true, y_pred):
    # 실제값과 예측값의 크기가 같은지 확인 (값이 다르면 오류 발생)
    assert y_true.shape == y_pred.shape

    n_samples = y_true.shape[0]                      # 데이터 개수
    L_mid = np.linspace(1 / n_samples, 1, n_samples) # 대각선 값

    # 1) 예측값에 대한 지니계수
    pred_order = y_true[y_pred.argsort()] # y_pred 크기순으로 y_true 값 정렬
    L_pred = np.cumsum(pred_order) / np.sum(pred_order) # 로렌츠 곡선
    G_pred = np.sum(L_mid - L_pred)       # 예측 값에 대한 지니계수

    # 2) 예측이 완벽할 때 지니계수
    true_order = y_true[y_true.argsort()] # y_true 크기순으로 y_true 값 정렬
    L_true = np.cumsum(true_order) / np.sum(true_order) # 로렌츠 곡선
    G_true = np.sum(L_mid - L_true)       # 예측이 완벽할 때 지니계수

    # 정규화된 지니계수
    return G_pred / G_true

# %%
# LightGBM용 gini() 함수
def gini(preds, dtrain):
    labels = dtrain.get_label()
    return 'gini', eval_gini(labels, preds), True # 반환값

# %% [markdown]
# ### 8.4.2 하이퍼파라미터 최적화

# %% [markdown]
# * 데이터셋 준비
# 베이지안 최적화를 위한 데이터셋 준비

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

bayes_dtrain = lgb.Dataset(X_train, y_train)
bayes_dvalid = lgb.Dataset(X_valid, y_valid)

# %%
# 베이지안 최적화를 위한 하이퍼파라미터 범위
param_bounds = {
    'num_leaves': (30, 40),
    'lambda_l1': (0.7, 0.9),
    'lambda_l2': (0.9, 1),
    'feature_fraction': (0.6, 0.7),
    'bagging_fraction': (0.6, 0.9),
    'min_child_samples': (6, 10),
    'min_child_weight': (10, 40)
}

fixed_params = {
    'objective': 'binary',
    'learning_rate':0.005,
    'bagging_freq': 1,
    'force_row_wise': True,
    'random_state': 1991
}

# %%
def eval_function(num_leaves, lambda_l1, lambda_l2, feature_fraction, bagging_fraction, min_child_samples, min_child_weight):
    params ={
        'num_leaves': int(round(num_leaves)),
        'lambda_l1': lambda_l1,
        'lambda_l2': lambda_l2,
        'feature_fraction': feature_fraction,
        'bagging_fraction': bagging_fraction,
        'min_child_samples': int(round(min_child_samples)),
        'feature_pre_filter': False
    }
    
    params.update(fixed_params)
    
    print('하이퍼파라미터:', params)
    
    lgb_model = lgb.train(params=params,
                          train_set=bayes_dtrain,
                          num_boost_round=2500,
                          valid_sets=bayes_dvalid,
                          feval=gini,
                          early_stopping_rounds=300,
                          verbose_eval=False)
    
    preds = lgb_model.predict(X_valid)
    
    gini_score = eval_gini(y_valid, preds)
    print(f'지니계수 : {gini_score}\n')
    
    return gini_score

# %%
from bayes_opt import BayesianOptimization

optimzer = BayesianOptimization(f=eval_function, pbounds=param_bounds, random_state=0)

# %%
optimzer.maximize(init_points=3, n_iter=6)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | min_ch... | min_ch... | num_le... |
# -------------------------------------------------------------------------------------------------------------
# 하이퍼파라미터: {'num_leaves': 39, 'lambda_l1': 0.7766883037651555, 'lambda_l2': 0.9791725038082665, 'feature_fraction': 0.6963662760501029, 'bagging_fraction': 0.867531900234624, 'min_child_samples': 8, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2825910724443365
#
# |  1        |  0.2826   |  0.8675   |  0.6964   |  0.7767   |  0.9792   |  8.116    |  27.04    |  39.26    |
# 하이퍼파라미터: {'num_leaves': 40, 'lambda_l1': 0.7040436794880651, 'lambda_l2': 0.9832619845547939, 'feature_fraction': 0.608712929970154, 'bagging_fraction': 0.6213108174593661, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.28415902809757554
#
# |  2        |  0.2842   |  0.6213   |  0.6087   |  0.704    |  0.9833   |  9.113    |  36.1     |  39.79    |
# 하이퍼파라미터: {'num_leaves': 39, 'lambda_l1': 0.8561058352572911, 'lambda_l2': 0.9118274425868933, 'feature_fraction': 0.6461479362252931, 'bagging_fraction': 0.8397475692650171, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.283711689475886
#
# |  3        |  0.2837   |  0.8397   |  0.6461   |  0.8561   |  0.9118   |  8.56     |  14.3     |  39.45    |
# 하이퍼파라미터: {'num_leaves': 30, 'lambda_l1': 0.7529111224209254, 'lambda_l2': 0.9774233689434216, 'feature_fraction': 0.6414661939990524, 'bagging_fraction': 0.7565544965250215, 'min_child_samples': 8, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2838561953497827
#
# |  4        |  0.2839   |  0.7566   |  0.6415   |  0.7529   |  0.9774   |  7.825    |  27.05    |  30.19    |
# 하이퍼파라미터: {'num_leaves': 34, 'lambda_l1': 0.8233867993749514, 'lambda_l2': 0.9943748078514624, 'feature_fraction': 0.6612095722722421, 'bagging_fraction': 0.7852906491227631, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2837317780446388
#
# |  5        |  0.2837   |  0.7853   |  0.6612   |  0.8234   |  0.9944   |  8.727    |  20.79    |  34.37    |
# 하이퍼파라미터: {'num_leaves': 30, 'lambda_l1': 0.8444997594874222, 'lambda_l2': 0.9234023852202012, 'feature_fraction': 0.6593983245038058, 'bagging_fraction': 0.8977977822397395, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2832427338073865
#
# |  6        |  0.2832   |  0.8978   |  0.6594   |  0.8445   |  0.9234   |  8.619    |  10.55    |  30.09    |
# 하이퍼파라미터: {'num_leaves': 37, 'lambda_l1': 0.7738449330497988, 'lambda_l2': 0.9032695189818599, 'feature_fraction': 0.6606341064409726, 'bagging_fraction': 0.7666713964943057, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2834685522877747
#
# |  7        |  0.2835   |  0.7667   |  0.6606   |  0.7738   |  0.9033   |  8.769    |  29.31    |  36.6     |
# 하이퍼파라미터: {'num_leaves': 40, 'lambda_l1': 0.8720080277156884, 'lambda_l2': 0.9616899145783075, 'feature_fraction': 0.6653269845316252, 'bagging_fraction': 0.6757553513860937, 'min_child_samples': 9, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.28314098488316614
#
# |  8        |  0.2831   |  0.6758   |  0.6653   |  0.872    |  0.9617   |  9.202    |  37.82    |  39.93    |
# 하이퍼파라미터: {'num_leaves': 36, 'lambda_l1': 0.862092450221885, 'lambda_l2': 0.900511488097541, 'feature_fraction': 0.6556247435580953, 'bagging_fraction': 0.7236613926476847, 'min_child_samples': 8, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2837785785870593
#
# |  9        |  0.2838   |  0.7237   |  0.6556   |  0.8621   |  0.9005   |  8.223    |  16.8     |  36.38    |
# 하이퍼파라미터: {'num_leaves': 32, 'lambda_l1': 0.829932662510154, 'lambda_l2': 0.9309382272206734, 'feature_fraction': 0.6952194054160209, 'bagging_fraction': 0.6675659367709144, 'min_child_samples': 8, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2843618344916569
#
# |  10       |  0.2844   |  0.6676   |  0.6952   |  0.8299   |  0.9309   |  7.88     |  28.6     |  31.94    |
# 하이퍼파라미터: {'num_leaves': 30, 'lambda_l1': 0.7873167947151679, 'lambda_l2': 0.9968661597281969, 'feature_fraction': 0.6942578276667516, 'bagging_fraction': 0.7759947252989496, 'min_child_samples': 8, 'feature_pre_filter': False, 'objective': 'binary', 'learning_rate': 0.005, 'bagging_freq': 1, 'force_row_wise': True, 'random_state': 1991}
# [LightGBM] [Info] Number of positive: 17383, number of negative: 458786
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036506 -> initscore=-3.273091
# [LightGBM] [Info] Start training from score -3.273091
# 지니계수 : 0.2837389635089452
#
# |  11       |  0.2837   |  0.776    |  0.6943   |  0.7873   |  0.9969   |  7.808    |  26.93    |  30.37    |
# =============================================================================================================

# %%
max_params = optimzer.max['params']
max_params
# Out:
# {'bagging_fraction': 0.6675659367709144,
#  'feature_fraction': 0.6952194054160209,
#  'lambda_l1': 0.829932662510154,
#  'lambda_l2': 0.9309382272206734,
#  'min_child_samples': 7.8802172313670225,
#  'min_child_weight': 28.604068940720285,
#  'num_leaves': 31.937139259095634}

# %%
max_params['num_leaves'] = int(round(max_params['num_leaves']))
max_params['min_child_samples'] = int(round(max_params['min_child_samples']))

# %%
max_params.update(fixed_params)

# %%
max_params
# Out:
# {'bagging_fraction': 0.6675659367709144,
#  'feature_fraction': 0.6952194054160209,
#  'lambda_l1': 0.829932662510154,
#  'lambda_l2': 0.9309382272206734,
#  'min_child_samples': 8,
#  'min_child_weight': 28.604068940720285,
#  'num_leaves': 32,
#  'objective': 'binary',
#  'learning_rate': 0.005,
#  'bagging_freq': 1,
#  'force_row_wise': True,
#  'random_state': 1991}

# %% [markdown]
# ### 8.4.3 모델 훈련 및 성능 검증

# %%
from sklearn.model_selection import StratifiedKFold

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1991)

oof_val_preds = np.zeros(X.shape[0])
oof_test_preds = np.zeros(X_test.shape[0])

for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    print('#'*40, f'폴드 {idx+1}/ 폴드 {folds.n_splits}', '#'*40)
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]
    
    dtrain = lgb.Dataset(X_train, y_train)
    dvalid = lgb.Dataset(X_valid, y_valid)
    
    lgb_model = lgb.train(params=max_params,
                          train_set=dtrain,
                          num_boost_round=2500,
                          valid_sets=dvalid,
                          feval=gini,
                          early_stopping_rounds=300,
                          verbose_eval=100)
    
    oof_test_preds += lgb_model.predict(X_test)/folds.n_splits
    oof_val_preds[valid_idx] += lgb_model.predict(X_valid)
    
    gini_score = eval_gini(y_valid, oof_val_preds[valid_idx])
    print(f'폴드 {idx+1} 지니계수: {gini_score}\n')
# Out:
# ######################################## 폴드 1/ 폴드 5 ########################################
# [LightGBM] [Info] Number of positive: 17355, number of negative: 458814
# [LightGBM] [Info] Total Bins 1554
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 216
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036447 -> initscore=-3.274764
# [LightGBM] [Info] Start training from score -3.274764
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's binary_logloss: 0.15429	valid_0's gini: 0.265543
# [200]	valid_0's binary_logloss: 0.153238	valid_0's gini: 0.272793
# [300]	valid_0's binary_logloss: 0.152647	valid_0's gini: 0.277665
# [400]	valid_0's binary_logloss: 0.152282	valid_0's gini: 0.28162
# [500]	valid_0's binary_logloss: 0.152039	valid_0's gini: 0.285037
# [600]	valid_0's binary_logloss: 0.15187	valid_0's gini: 0.287802
# [700]	valid_0's binary_logloss: 0.151756	valid_0's gini: 0.289643
# [800]	valid_0's binary_logloss: 0.151675	valid_0's gini: 0.291127
# [900]	valid_0's binary_logloss: 0.151608	valid_0's gini: 0.29257
# [1000]	valid_0's binary_logloss: 0.151554	valid_0's gini: 0.293906
# [1100]	valid_0's binary_logloss: 0.151512	valid_0's gini: 0.294966
# [1200]	valid_0's binary_logloss: 0.151475	valid_0's gini: 0.295882
# [1300]	valid_0's binary_logloss: 0.151454	valid_0's gini: 0.296343
# [1400]	valid_0's binary_logloss: 0.15144	valid_0's gini: 0.29666
# [1500]	valid_0's binary_logloss: 0.151416	valid_0's gini: 0.297242
# [1600]	valid_0's binary_logloss: 0.151406	valid_0's gini: 0.297385
# [1700]	valid_0's binary_logloss: 0.151399	valid_0's gini: 0.297475
# [1800]	valid_0's binary_logloss: 0.151387	valid_0's gini: 0.297828
# [1900]	valid_0's binary_logloss: 0.151375	valid_0's gini: 0.298143
# [2000]	valid_0's binary_logloss: 0.15138	valid_0's gini: 0.297936
# [2100]	valid_0's binary_logloss: 0.151377	valid_0's gini: 0.298016
# Early stopping, best iteration is:
# [1871]	valid_0's binary_logloss: 0.151374	valid_0's gini: 0.298232
# 폴드 1 지니계수: 0.298232056177961
#
# ######################################## 폴드 2/ 폴드 5 ########################################
# [LightGBM] [Info] Number of positive: 17355, number of negative: 458814
# [LightGBM] [Info] Total Bins 1560
# [LightGBM] [Info] Number of data points in the train set: 476169, number of used features: 216
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036447 -> initscore=-3.274764
# [LightGBM] [Info] Start training from score -3.274764
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's binary_logloss: 0.154384	valid_0's gini: 0.254866
# [200]	valid_0's binary_logloss: 0.153397	valid_0's gini: 0.260835
# [300]	valid_0's binary_logloss: 0.152852	valid_0's gini: 0.265879
# [400]	valid_0's binary_logloss: 0.152526	valid_0's gini: 0.269579
# [500]	valid_0's binary_logloss: 0.152323	valid_0's gini: 0.272304
# [600]	valid_0's binary_logloss: 0.152181	valid_0's gini: 0.274734
# [700]	valid_0's binary_logloss: 0.152093	valid_0's gini: 0.276258
# [800]	valid_0's binary_logloss: 0.152014	valid_0's gini: 0.278074
# [900]	valid_0's binary_logloss: 0.151956	valid_0's gini: 0.27946
# [1000]	valid_0's binary_logloss: 0.151908	valid_0's gini: 0.280633
# [1100]	valid_0's binary_logloss: 0.151869	valid_0's gini: 0.281746
# [1200]	valid_0's binary_logloss: 0.15184	valid_0's gini: 0.282535
# [1300]	valid_0's binary_logloss: 0.151817	valid_0's gini: 0.283083
# [1400]	valid_0's binary_logloss: 0.151799	valid_0's gini: 0.283511
# [1500]	valid_0's binary_logloss: 0.151784	valid_0's gini: 0.283845
# [1600]	valid_0's binary_logloss: 0.15177	valid_0's gini: 0.284318
# [1700]	valid_0's binary_logloss: 0.151756	valid_0's gini: 0.284738
# [1800]	valid_0's binary_logloss: 0.151743	valid_0's gini: 0.285012
# [1900]	valid_0's binary_logloss: 0.151736	valid_0's gini: 0.285279
# [2000]	valid_0's binary_logloss: 0.151726	valid_0's gini: 0.285518
# [2100]	valid_0's binary_logloss: 0.151721	valid_0's gini: 0.285612
# [2200]	valid_0's binary_logloss: 0.151716	valid_0's gini: 0.285747
# [2300]	valid_0's binary_logloss: 0.151716	valid_0's gini: 0.285728
# [2400]	valid_0's binary_logloss: 0.151712	valid_0's gini: 0.285865
# [2500]	valid_0's binary_logloss: 0.15171	valid_0's gini: 0.28589
# Did not meet early stopping. Best iteration is:
# [2478]	valid_0's binary_logloss: 0.151709	valid_0's gini: 0.285962
# 폴드 2 지니계수: 0.28596178904775243
#
# ######################################## 폴드 3/ 폴드 5 ########################################
# [LightGBM] [Info] Number of positive: 17356, number of negative: 458814
# [LightGBM] [Info] Total Bins 1558
# [LightGBM] [Info] Number of data points in the train set: 476170, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036449 -> initscore=-3.274707
# [LightGBM] [Info] Start training from score -3.274707
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's binary_logloss: 0.154286	valid_0's gini: 0.259513
# [200]	valid_0's binary_logloss: 0.15323	valid_0's gini: 0.266002
# [300]	valid_0's binary_logloss: 0.152642	valid_0's gini: 0.270509
# [400]	valid_0's binary_logloss: 0.152281	valid_0's gini: 0.274261
# [500]	valid_0's binary_logloss: 0.152044	valid_0's gini: 0.277163
# [600]	valid_0's binary_logloss: 0.151886	valid_0's gini: 0.279543
# [700]	valid_0's binary_logloss: 0.15178	valid_0's gini: 0.28114
# [800]	valid_0's binary_logloss: 0.151706	valid_0's gini: 0.282338
# [900]	valid_0's binary_logloss: 0.151659	valid_0's gini: 0.283213
# [1000]	valid_0's binary_logloss: 0.151624	valid_0's gini: 0.283851
# [1100]	valid_0's binary_logloss: 0.1516	valid_0's gini: 0.284199
# [1200]	valid_0's binary_logloss: 0.15158	valid_0's gini: 0.284703
# [1300]	valid_0's binary_logloss: 0.151572	valid_0's gini: 0.284809
# [1400]	valid_0's binary_logloss: 0.151565	valid_0's gini: 0.284954
# [1500]	valid_0's binary_logloss: 0.151562	valid_0's gini: 0.285055
# [1600]	valid_0's binary_logloss: 0.151558	valid_0's gini: 0.285131
# [1700]	valid_0's binary_logloss: 0.151554	valid_0's gini: 0.285243
# [1800]	valid_0's binary_logloss: 0.15156	valid_0's gini: 0.285003
# [1900]	valid_0's binary_logloss: 0.151561	valid_0's gini: 0.285037
# Early stopping, best iteration is:
# [1675]	valid_0's binary_logloss: 0.151551	valid_0's gini: 0.285306
# 폴드 3 지니계수: 0.28530594046995933
#
# ######################################## 폴드 4/ 폴드 5 ########################################
# [LightGBM] [Info] Number of positive: 17355, number of negative: 458815
# [LightGBM] [Info] Total Bins 1555
# [LightGBM] [Info] Number of data points in the train set: 476170, number of used features: 216
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036447 -> initscore=-3.274766
# [LightGBM] [Info] Start training from score -3.274766
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's binary_logloss: 0.154361	valid_0's gini: 0.253625
# [200]	valid_0's binary_logloss: 0.153353	valid_0's gini: 0.259626
# [300]	valid_0's binary_logloss: 0.152808	valid_0's gini: 0.263842
# [400]	valid_0's binary_logloss: 0.152485	valid_0's gini: 0.267293
# [500]	valid_0's binary_logloss: 0.152284	valid_0's gini: 0.270003
# [600]	valid_0's binary_logloss: 0.152146	valid_0's gini: 0.272167
# [700]	valid_0's binary_logloss: 0.152057	valid_0's gini: 0.273745
# [800]	valid_0's binary_logloss: 0.151994	valid_0's gini: 0.27501
# [900]	valid_0's binary_logloss: 0.151943	valid_0's gini: 0.276131
# [1000]	valid_0's binary_logloss: 0.151907	valid_0's gini: 0.27711
# [1100]	valid_0's binary_logloss: 0.151884	valid_0's gini: 0.277755
# [1200]	valid_0's binary_logloss: 0.15186	valid_0's gini: 0.27842
# [1300]	valid_0's binary_logloss: 0.151841	valid_0's gini: 0.27893
# [1400]	valid_0's binary_logloss: 0.15183	valid_0's gini: 0.279299
# [1500]	valid_0's binary_logloss: 0.151828	valid_0's gini: 0.279436
# [1600]	valid_0's binary_logloss: 0.151823	valid_0's gini: 0.279571
# [1700]	valid_0's binary_logloss: 0.151827	valid_0's gini: 0.279488
# [1800]	valid_0's binary_logloss: 0.15182	valid_0's gini: 0.279697
# [1900]	valid_0's binary_logloss: 0.151824	valid_0's gini: 0.279682
# [2000]	valid_0's binary_logloss: 0.151825	valid_0's gini: 0.279746
# Early stopping, best iteration is:
# [1770]	valid_0's binary_logloss: 0.151819	valid_0's gini: 0.279692
# 폴드 4 지니계수: 0.2796921259917623
#
# ######################################## 폴드 5/ 폴드 5 ########################################
# [LightGBM] [Info] Number of positive: 17355, number of negative: 458815
# [LightGBM] [Info] Total Bins 1558
# [LightGBM] [Info] Number of data points in the train set: 476170, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.036447 -> initscore=-3.274766
# [LightGBM] [Info] Start training from score -3.274766
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's binary_logloss: 0.154435	valid_0's gini: 0.261343
# [200]	valid_0's binary_logloss: 0.153443	valid_0's gini: 0.268446
# [300]	valid_0's binary_logloss: 0.152897	valid_0's gini: 0.27247
# [400]	valid_0's binary_logloss: 0.152563	valid_0's gini: 0.276621
# [500]	valid_0's binary_logloss: 0.152339	valid_0's gini: 0.280185
# [600]	valid_0's binary_logloss: 0.152187	valid_0's gini: 0.283192
# [700]	valid_0's binary_logloss: 0.15207	valid_0's gini: 0.285676
# [800]	valid_0's binary_logloss: 0.151984	valid_0's gini: 0.28771
# [900]	valid_0's binary_logloss: 0.151917	valid_0's gini: 0.289441
# [1000]	valid_0's binary_logloss: 0.151866	valid_0's gini: 0.29075
# [1100]	valid_0's binary_logloss: 0.151824	valid_0's gini: 0.291832
# [1200]	valid_0's binary_logloss: 0.151791	valid_0's gini: 0.29279
# [1300]	valid_0's binary_logloss: 0.151767	valid_0's gini: 0.293485
# [1400]	valid_0's binary_logloss: 0.151752	valid_0's gini: 0.293861
# [1500]	valid_0's binary_logloss: 0.151734	valid_0's gini: 0.294313
# [1600]	valid_0's binary_logloss: 0.151715	valid_0's gini: 0.294869
# [1700]	valid_0's binary_logloss: 0.151706	valid_0's gini: 0.29519
# [1800]	valid_0's binary_logloss: 0.151694	valid_0's gini: 0.295517
# [1900]	valid_0's binary_logloss: 0.151685	valid_0's gini: 0.295731
# [2000]	valid_0's binary_logloss: 0.151678	valid_0's gini: 0.296018
# [2100]	valid_0's binary_logloss: 0.151678	valid_0's gini: 0.296032
# [2200]	valid_0's binary_logloss: 0.151677	valid_0's gini: 0.296048
# [2300]	valid_0's binary_logloss: 0.15168	valid_0's gini: 0.295934
# [2400]	valid_0's binary_logloss: 0.151679	valid_0's gini: 0.295918
# [2500]	valid_0's binary_logloss: 0.151685	valid_0's gini: 0.295764
# Did not meet early stopping. Best iteration is:
# [2234]	valid_0's binary_logloss: 0.151673	valid_0's gini: 0.296116
# 폴드 5 지니계수: 0.2961158963127309

# %%
print('OOF 검증 데이터 지니계수 :', eval_gini(y, oof_val_preds))
# Out:
# OOF 검증 데이터 지니계수 : 0.28896687232618584

# %% [markdown]
# ### 8.4.4 예측 및 결과 제출

# %%
submission['target'] = oof_test_preds
submission.to_csv('submission.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_47/2622142076.py in <module>
# ----> 1 submission['target'] = oof_test_preds
#       2 submission.to_csv('submission.csv')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# -> 4504             com.require_length_match(value, self.index)
#    4505         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4506
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/common.py in require_length_match(data, index)
#     530     if len(data) != len(index):
#     531         raise ValueError(
# --> 532             "Length of values "
#     533             f"({len(data)}) "
#     534             "does not match length of index "
#
# ValueError: Length of values (119043) does not match length of index (892816)
