# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %matplotlib inline

# %%
# 한글깨짐 현상 방지
# plt.rc('font', family='NanumGothic')
# mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('./data/df_final_2.csv')
df.head()
# Out:
#        Country          Region  Rank     Score       GDP  Social Support  \
# 0  Switzerland  Western Europe   1.0  1.000000  0.826132        0.962403
# 1      Iceland  Western Europe   2.0  0.994524  0.770412        1.000000
# 2      Denmark  Western Europe   3.0  0.987363  0.784113        0.970297
# 3       Norway  Western Europe   4.0  0.986310  0.863099        0.949167
# 4       Canada   North America   5.0  0.966302  0.784592        0.943219
#
#      Health  Year
# 0  0.918244  2015
# 1  0.924496  2015
# 2  0.853099  2015
# 3  0.863409  2015
# 4  0.883326  2015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         1231 non-null   object
#  1   Region          1184 non-null   object
#  2   Rank            1230 non-null   float64
#  3   Score           1230 non-null   float64
#  4   GDP             1230 non-null   float64
#  5   Social Support  1230 non-null   float64
#  6   Health          1230 non-null   float64
#  7   Year            1231 non-null   int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 77.1+ KB

# %%
df = df[:-1]

# %%
plt.title('상관관계표')
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/513437765.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# * Score가 높을수록, GDP가 높을수록, Health할수록 행복 지수가 높았다 -> 행복의 척도는 경제력과 건강?
# * GDP와 Health가 양의 상관관계를 가지고 있다. 경제력이 좋을수록 더 건강하다?

# %%
sns.pairplot(df)

# %%
df_2022 = df[df['Year'] == 2022]

# %%
df_2022.groupby(by='Region').mean().sort_values(by='Score', ascending=False)['Score']
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/402945523.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_2022.groupby(by='Region').mean().sort_values(by='Score', ascending=False)['Score']
# Region
# Australia and New Zealand       0.881853
# North America                   0.848625
# Western Europe                  0.838122
# Latin America and Caribbean     0.651478
# Central and Eastern Europe      0.645306
# East Asia                       0.632453
# Southeast Asia                  0.558919
# Middle East and North Africa    0.518652
# Sub-Saharan Africa              0.395044
# South Asia                      0.343579
# Name: Score, dtype: float64

# %%
def draw_region(year, row):
    plt.title(f'{year} 대륙별 {row}')
    part = df[df['Year'] == year]
    part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
    plt.show()

# %%
draw_region(2022, 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
draw_region(2022, 'GDP')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
draw_region(2021, 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
draw_region(2020, 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
draw_region(2019, 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
draw_region(2018, 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/551635694.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
def whole_year_region(row):
    f = plt.figure(figsize=(40, 20))
    for i in range(8):
        f.add_subplot(4, 2, i+1)
        year = 2015 + i
        plt.gca().set_title(f'{year} 대륙별 {row}')
        part = df[df['Year'] == year]
        part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
    plt.show()

# %%
whole_year_region('Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
whole_year_region('GDP')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
whole_year_region('Health')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %%
whole_year_region('Social Support')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/4240176187.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part.groupby(by='Region').mean().sort_values(by=row)[row].plot(kind='barh', x=row)

# %% [markdown]
# * 2021 2022 Health 수치가 왜저러지?

# %%
df.groupby('Year').mean()['Social Support'].plot(kind='line')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/1618290513.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Year').mean()['Social Support'].plot(kind='line')
# <Axes: xlabel='Year'>

# %%
def feature_year_tracking(region, feature): 
    plt.title(f'{region} {feature}')
    plt.ylabel(feature)
    df[df['Region'] == region].groupby('Year').mean()[feature].plot(kind='line', label=feature)
    plt.grid()
    plt.legend()
    plt.show()

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Southeast Asia', 'Central and Eastern Europe', 'East Asia',
#        'Sub-Saharan Africa', 'South Asia', nan,
#        'Commonwealth of Independent States'], dtype=object)

# %%
feature_year_tracking('East Asia', 'Social Support')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/1509276381.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Region'] == region].groupby('Year').mean()[feature].plot(kind='line', label=feature)

# %%
feature_year_tracking('East Asia', 'Score')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/1509276381.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Region'] == region].groupby('Year').mean()[feature].plot(kind='line', label=feature)

# %%
feature_year_tracking('East Asia', 'GDP')
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/1509276381.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['Region'] == region].groupby('Year').mean()[feature].plot(kind='line', label=feature)

# %%
df[df['Country'] == 'South Korea']
# Out:
#           Country     Region  Rank     Score       GDP  Social Support  \
# 46    South Korea  East Asia  47.0  0.662384  0.736273        0.683012
# 215   South Korea  East Asia  57.0  0.634062  0.745219        0.610128
# 369   South Korea  East Asia  55.0  0.649257  0.749254        0.700542
# 526   South Korea  East Asia  57.0  0.628305  0.604008        0.732360
# 679   South Korea  East Asia  54.0  0.618796  0.772565        0.750616
# 842   South Korea  East Asia  61.0  0.630604  0.810386        0.732479
# 996   South Korea  East Asia  62.0  0.624553  0.801256        0.646758
# 1142  South Korea  East Asia  59.0  0.651837  0.837936        0.671212
#
#         Health  Year
# 46    0.941604  2015
# 215   0.930392  2016
# 369   0.948100  2017
# 526   0.927184  2018
# 679   0.907975  2019
# 842   0.898690  2020
# 996   0.892977  2021
# 1142  0.892781  2022

# %%
def draw_country_year_traking(country, feature):
    plt.title(f'연도별 {country} {feature}')
    plt.ylabel(feature)
    part = df[df['Country'] == country]
    sns.lineplot(x='Year', y=feature, data=part)
    plt.grid()
    plt.legend()
    plt.show()

# %%
draw_country_year_traking('South Korea', 'GDP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('South Korea', 'Health')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('South Korea', 'Social Support')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('South Korea', 'Score')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('South Korea', 'Rank')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# * 한국의 경우 경제 성장은 한것 같지만 나머지 척도 값이 많이 안좋아졌다. 이에 따라 Score가 좋아진것 같아보여도 전체 순위는 많이 안좋아 진것 같다.

# %%
list(df[df['Year'] == 2016].sort_values('Rank')['Country'])[0]
# Out:
# 'Denmark'

# %%
for i in range(8):
    year = 2015 + i
    top = list(df[df['Year'] == year].sort_values('Rank')['Country'])[0]
    print(f'{year}: {top}')
# Out:
# 2015: Switzerland
# 2016: Denmark
# 2017: Norway
# 2018: Finland
# 2019: Finland
# 2020: Finland
# 2021: Finland
# 2022: Finland

# %%
for i in range(8):
    year = 2015 + i
    top = list(df[df['Year'] == year].sort_values('Score', ascending=False)['Country'])[0]
    print(f'{year}: {top}')
# Out:
# 2015: Switzerland
# 2016: Denmark
# 2017: Norway
# 2018: Finland
# 2019: Finland
# 2020: Finland
# 2021: Finland
# 2022: Finland

# %%
draw_country_year_traking('Finland', 'GDP')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('Finland', 'Health')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
draw_country_year_traking('Finland', 'Social Support')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# * 데이터 전처리를 다시 해봐야 할것 같다

# %%
def region_boxplot(feature):
    plt.title(f'Region별 {feature}')
    ax = sns.boxplot(y=feature, x='Region', data=df)
    ax.set_xticklabels(ax.get_xticklabels(),rotation = 70)
    plt.show()

# %%
region_boxplot('Score')

# %%
region_boxplot('GDP')

# %%
region_boxplot('Health')

# %%
region_boxplot('Social Support')

# %%
def feature_year_dist(feature):
    plt.title(f'연도별 {feature}')
    sns.boxplot(y=feature, x='Year', data=df)
    plt.show()

# %%
feature_year_dist('GDP')

# %%
feature_year_dist('Health')

# %%
feature_year_dist('Social Support')

# %% [markdown]
# * 아무래도 전처리를 다시 해봐야할것 같다.

# %%
df.describe()
# Out:
#               Rank        Score          GDP  Social Support       Health  \
# count  1230.000000  1230.000000  1230.000000     1230.000000  1230.000000
# mean     77.421951     0.545004     0.533200        0.713764     0.600870
# std      44.486241     0.226212     0.229608        0.200353     0.230386
# min       1.000000     0.000000     0.000000        0.000000     0.000000
# 25%      39.000000     0.378744     0.363068        0.603567     0.429331
# 50%      77.000000     0.543088     0.565088        0.754476     0.652822
# 75%     116.000000     0.701522     0.714682        0.878803     0.767629
# max     158.000000     1.000000     1.000000        1.000000     1.000000
#
#               Year
# count  1230.000000
# mean   2018.447154
# std       2.282716
# min    2015.000000
# 25%    2016.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2022.000000

# %%
df.groupby(by='Year').mean()
# Out:
# /var/folders/dg/0sf74rv51pj2sr7xt3hrvwkm0000gn/T/ipykernel_30130/1805976648.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by='Year').mean()
#            Rank     Score       GDP  Social Support    Health
# Year
# 2015  79.493671  0.534274  0.500549        0.706764  0.614737
# 2016  78.980892  0.536071  0.522883        0.670707  0.585261
# 2017  78.000000  0.549343  0.526372        0.738183  0.580669
# 2018  78.500000  0.522724  0.425310        0.737979  0.579948
# 2019  78.500000  0.519548  0.537498        0.744344  0.635621
# 2020  77.000000  0.554455  0.565357        0.746725  0.608947
# 2021  75.000000  0.565866  0.558059        0.676890  0.579890
# 2022  73.500000  0.581424  0.638499        0.686260  0.622262

# %%
df2022 = df[df['Year'] == 2022]

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
data = dict(type='choropleth',
            locations = df2022["Country"],
            locationmode = 'country names',
            z = df2022["Score"],
            text = df2022["Country"],
            colorbar = {"title":"2022 Happiness Score"})

layout = dict(title = "2022 Geographical Visualization of Happiness Score",
              geo = dict(showframe = True, projection = {"type" : "azimuthal equal area"}))

happiness_map = go.Figure(data = [data], layout=layout)
iplot(happiness_map)
