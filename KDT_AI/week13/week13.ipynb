# %% [markdown]
# ### <b>실전 프로젝트 - CNN을 활용한 풍경(Scene) 이미지 분류</b>
#
# * 한 장의 풍경 이미지가 주어졌을 때, 어떠한 카테고리(category)에 속하는지 맞히는 <b>분류 모델</b>을 만드세요.
# * 다음의 세 가지 대표적인 CNN 모델을 실습합니다.
#     1. [LeNet (1998)](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
#     2. [AlexNet (2012 NIPS)](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf)
#     3. [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385)
# * 성능을 올릴 수 있는 두 가지 심화 기법을 실습합니다.
#     1. [Mixup (ICLR 2018)](https://arxiv.org/abs/1710.09412): 데이터 증진 기법의 일종으로 정확도를 높입니다.
#     2. Transfer Learning: 학습 속도와 정확도를 모두 향상시킬 수 있습니다.
# * 본 프로젝트는 <b>총 7개의 문제</b>로 구성됩니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
#     * 단계적으로 문제를 풀어나가는 과정에서 CNN 기반의 고성능 분류 모델을 학습하는 방법을 이해할 수 있습니다.
# * (참고) 본 실습 코드에서는 빠른 결과 도출을 위해 30~50 epoch 정도만 학습합니다.
#     * 풍경 데이터셋에 대하여 완전히 학습시키기 위해서는 100 epoch 이상의 학습이 필요합니다.

# %% [markdown]
# #### <b>(알아보기) 지난 프로젝트 Review</b>
#
# * 지난 프로젝트에서는 Scene Classification 데이터셋에 대하여 간단한 기계학습 모델을 학습했습니다.
#     1. 선형 분류 모델(Linear Models for Classification)
#     2. KNN (K-Nearest Neighbors)
# * 하지만, 두 기법 모두 정확도(accuracy)가 <b>60% 미만</b>으로 낮게 나온다는 <b>한계점</b>이 존재했습니다.
# * 본 실습에서는 CNN을 이용해 정확도를 <b>최소한 90% 이상으로</b> 높입니다.
#     * 실제로 현업에서 많이 사용되는 테크닉을 이용해 최대한 정확도를 끌어올려 봅시다.

# %% [markdown]
# #### <b>Problem 1. 데이터셋 다운로드 및 분석하기</b>
#
# * [PyTorch용 Scene Classification 데이터셋 저장소](https://github.com/ndb796/Scene-Classification-Dataset-Split)
#     * 참고: [원본 Kaggle 데이터셋 링크](https://www.kaggle.com/nitishabharathi/scene-classification)
#     * 본 데이터셋은 <b>저작권이 없는(No Copyright)</b> [CC0: Public Domain](https://creativecommons.org/publicdomain/zero/1.0/) 라이센스를 따라므로, 자유롭게 변형할 수 있습니다.
# * PyTorch에서 곧바로 불러와 사용할 수 있도록 구성된 데이터셋입니다.
# * 다음의 명령어를 이용해 데이터셋을 다운로드할 수 있습니다.
#
# <pre>
# # 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# # 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# </pre>

# %%
# 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split 
# 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# Out:
# Cloning into 'Scene-Classification-Dataset-Split'...
# remote: Enumerating objects: 17038, done.
# remote: Total 17038 (delta 0), reused 0 (delta 0), pack-reused 17038
# Receiving objects: 100% (17038/17038), 136.02 MiB | 19.37 MiB/s, done.
# /kaggle/working/Scene-Classification-Dataset-Split

# %% [markdown]
# #### <b>(알아보기) 데이터셋 설명</b>
#
# * 본 PyTorch용 장면(scene) 데이터셋은 17,034개의 다양한 <b>자연 경치(scene)</b> 이미지로 구성되어 있습니다.
# * 총 6개의 클래스(class)로 구성됩니다.
#
# <pre>
# 클래스 0. 빌딩(buildings)
# 클래스 1. 숲(forests)
# 클래스 2. 빙하(glacier)
# 클래스 3. 산(mountains)
# 클래스 4. 바다(sea)
# 클래스 5. 거리(street)
# </pre>
#
# * 각 이미지는 공통적으로 64 X 64 크기를 가집니다.
# * 데이터셋 폴더 구성은 다음과 같습니다.
#
# <pre>
# Dataset/
#     train/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
#     val/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
# </pre>

# %% [markdown]
# #### <b>(알아보기) 클래스별 학습 이미지 개수 출력하기</b>
#
# * 클래스별 데이터의 개수를 계산합니다.
#     * os 라이브러리의 os.listdir()를 이용하여 이미지 폴더에 존재하는 파일 이름 목록을 얻을 수 있습니다.
#     * 클래스의 개수는 6개입니다.
# * 총 학습 데이터의 개수는 13,627개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 2,105개
# 클래스 1. 숲(forests): 2,205개
# 클래스 2. 빙하(glacier): 2,363개
# 클래스 3. 산(mountains): 2,438개
# 클래스 4. 바다(sea): 2,224개
# 클래스 5. 거리(street): 2,292개
# </pre>
#
# * 총 검증 데이터의 개수는 3,407개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 523개
# 클래스 1. 숲(forests): 540개
# 클래스 2. 빙하(glacier): 594개
# 클래스 3. 산(mountains): 599개
# 클래스 4. 바다(sea): 560개
# 클래스 5. 거리(street): 591개
# </pre>

# %%
import os


classes = ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']
train_path = 'train/'
val_path = 'val/'

print("[ 학습 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(train_path + classes[i]))}')

print("[ 검증 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(val_path + classes[i]))}')
# Out:
# [ 학습 데이터셋 ]
# 클래스 0의 개수: 2105
# 클래스 1의 개수: 2205
# 클래스 2의 개수: 2363
# 클래스 3의 개수: 2438
# 클래스 4의 개수: 2224
# 클래스 5의 개수: 2292
# [ 검증 데이터셋 ]
# 클래스 0의 개수: 523
# 클래스 1의 개수: 540
# 클래스 2의 개수: 594
# 클래스 3의 개수: 599
# 클래스 4의 개수: 560
# 클래스 5의 개수: 591

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * PyTorch의 <b>ImageFolder 라이브러리</b>를 이용하여 <b>자신만의 데이터셋</b>을 불러올 수 있습니다.
# * ImageFolder 라이브러리는 다음과 같이 <b>계층적인 폴더 구조</b>에서 데이터셋을 불러올 때 사용할 수 있습니다.
#     * 각 클래스명(class name)으로 된 폴더에 여러 장의 이미지가 들어가 있는 구조입니다.
#
# <pre>
# dataset/
#     class 0/
#         0.jpg
#         1.jpg
#         ...
#     class 1/
#         0.jpg
#         1.jpg
#         ...
#     ...
#     class 9/
#         0.jpg
#         1.jpg
#         ...
# </pre>
#
# * 기본적인 <b>데이터 증진(data augmentation)</b> 기법을 사용합니다.
#     * [RandomResizedCrop()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지의 일부를 잘라내어 특정 크기로 변형합니다.
#     * [RandomHorizontalFlip()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지를 좌우 반전합니다.
# * <b>정규화(normalization)를</b> 진행합니다.
#     * 일반적으로 많이 사용되는 ImageNet 데이터셋의 설정을 이용합니다.

# %%
import torch
from torchvision import datasets, transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device object

transforms_train = transforms.Compose([
    transforms.RandomResizedCrop((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_path, transforms_train)
val_dataset = datasets.ImageFolder(val_path, transforms_val)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset))
print('Validation dataset size:', len(val_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %% [markdown]
# #### <b>(알아보기) 이미지 시각화하기</b>
#
# * PyTorch로 불러온 데이터(torch.Tensor 객체)를 시각화해 봅시다.
# * Google Colab에 출력하기 위해서 NumPy 형태로 변형한 뒤에 Matplotlib을 이용합니다.
#     * torch.Tensor는 (Channel, Height, Width) 형식을 가집니다.
#     * numpy 객체는 (Height, Width, Channel) 형식을 가집니다.

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt


# 화면에 출력되는 이미지 크기를 적절하게 조절하기
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(image, title):
    # torch.Tensor => numpy 변환하기
    image = image.numpy().transpose((1, 2, 0))
    # 이미지 정규화(normalization) 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    # 화면에 이미지 출력하기
    plt.imshow(image)
    plt.title(title)
    plt.show()


# 학습 데이터셋에서 하나의 배치를 불러와 보기
iterator = iter(train_dataloader)

# 현재 배치에 포함된 이미지를 출력하기
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs[:4])
imshow(out, title=[class_names[x] for x in classes[:4]])

# %% [markdown]
# #### <b>Problem 2. Convolution 연산 이해하기</b>
#
# * Convolution 연산의 동작 원리를 이해할 필요가 있습니다.
# * <b>[그림 예시]</b> 아래 그림에서는 stride가 1이고, padding이 0일 때의 Convolution 연산 예시를 보입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
#
# * 입력 데이터의 높이: $height$
# * 입력 데이터의 너비: $width$
# * 필터의 높이: $filter\_height$
# * 필터의 너비: $filter\_width$
# * 스트라이드(stride): $stride$
# * 패딩 크기: $padding$
#
# <hr>
#
# * Convolution 연산 이후의 출력 차원은 다음과 같은 공식으로 계산할 수 있습니다. (나누기할 때 소수점 아래 버림)
#     * 출력 높이(output height) = $(height + 2 * padding - filter\\_height) / stride + 1$
#     * 출력 너비(output width) = $(width + 2 * padding - filter\\_width) / stride + 1$
#
# * <b>[문제]</b> 다음의 각 경우에 대하여 Convolution 연산을 수행한 뒤의 출력 차원을 쓰세요.
#     1. $height=32$, $width=32$, $filter\\_height=5$, $filter\\_width=5$, $stride=2$, $padding=2$일 때 → (16, 16)
#     2. $height=64$, $width=64$, $filter\\_height=3$, $filter\\_width=3$, $stride=1$, $padding=1$일 때 → (64, 64)
#     3. $height=16$, $width=16$, $filter\\_height=4$, $filter\\_width=4$, $stride=2$, $padding=1$일 때 → (8, 8)
#     4. $height=60$, $width=45$, $filter\\_height=8$, $filter\\_width=5$, $stride=3$, $padding=1$일 때 → (19, 15)
#
# * (Hint) 다음과 같은 Python 코드를 사용하여 간단히 계산할 수 있습니다.
#
# <pre>
# height = 16
# width = 16
# filter_height = 4
# filter_width = 4
# stride = 2
# padding = 1
#
# output_height = (height + 2 * padding - filter_height) // stride + 1
# output_width = (width + 2 * padding - filter_width) // stride + 1
#
# print('출력 높이:', output_height, '출력 너비:', output_width)
# </pre>
#
# * 실행 결과 예시
#
# <pre>
# 출력 높이: 8 출력 너비: 8
# </pre>

# %%
targets = [(32, 32, 5, 5, 2, 2), (64, 64, 3, 3, 1, 1), (16, 16, 4, 4, 2, 1), (60, 45, 8, 5, 3, 1)]

for item in targets:
    height, width, filter_height, filter_width, stride, padding = item
    
    output_height = (height + 2 * padding - filter_height) // stride + 1
    output_width = (width + 2 * padding - filter_width) // stride + 1
    
    print('출력 높이:', output_height, '출력 너비:', output_width)
# Out:
# 출력 높이: 16 출력 너비: 16
# 출력 높이: 64 출력 너비: 64
# 출력 높이: 8 출력 너비: 8
# 출력 높이: 19 출력 너비: 15

# %% [markdown]
# #### <b>(알아보기) Lenet 아키텍처 이해하기</b>
#
# * 기본적인 LeNet 아키텍처를 이해할 수 있습니다.
#     * Convolutional Neural Network를 최초로(1998년) 적용한 간단한 아키텍처입니다.
#     * Convolution 연산과 Pooling 연산이 사용됩니다.
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현한 것을 확인해 봅시다.
#     * 원본 논문과 완전히 동일하지는 않지만, 핵심 아이디어를 잘 표현한 아키텍처입니다.
#     * PyTorch에서는 모델에 별도로 Softmax 레이어를 두지 않고, 학습할 때 nn.CrossEntropyLoss()를 사용하는 것이 일반적입니다.

# %% [markdown]
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 20, kernel size: 5 X 5, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 50, kernel size: 5 X 5, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Fully Connected | # of neuron: 500
# 7 | Activation | ReLU
# 8 | Fully Connected | # of neuron: 6
# 9 | Softmax | 6 classes

# %%
import torch.nn as nn
import torch.nn.functional as F


class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (20 x 60 x 60)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (20 x 30 x 30)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (50 x 26 x 26)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (50 x 13 x 13)
        self.fc1 = nn.Linear(50 * 13 * 13, 500)
        # → 차원(dimension): (500)
        self.fc2 = nn.Linear(500, 6)
        # → 차원(dimension): (6)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = torch.flatten(x, 1) # 배치(batch)를 제외한 모든 차원 flatten하기
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# #### <b>(알아보기) 학습 및 평가 함수 이해하기</b>
#
# * 별도의 학습(train) 함수와 평가(validate) 함수를 작성합니다.

# %%
def train(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = criterion(outputs, targets) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)


def validate(net, epoch, val_dataloader):
    print('[ Validation epoch: %d ]' % epoch)
    net.eval() # 모델을 평가 모드로 설정
    val_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(val_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs) # 모델 입력하여 결과 계산
        val_loss += criterion(outputs, targets).item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Accuarcy:', 100. * correct / total)
    print('Average loss:', val_loss / total)
    return (100. * correct / total, val_loss / total)

# %% [markdown]
# #### <b>(알아보기) LeNet 학습하기</b>
#
# * 앞서 정의한 LeNet 네트워크를 학습합니다.
# * 학습률(learning rate)을 수정해보면서 결과를 확인해 봅시다.
#     * 만약 학습률이 너무 크다면, 발산하여 손실(loss) 값이 NaN으로 나오며 학습이 안 될 수 있습니다.

# %%
import time
import torch.optim as optim


net = LeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 51.55940412416526
# Train average loss: 0.03917611309706426
# [ Validation epoch: 1 ]
# Accuarcy: 62.57704725565013
# Average loss: 0.03096729756661234
# Model saved! (time elapsed: 18.752466678619385)
# [ Train epoch: 1 ]
# Train accuarcy: 57.885081089014456
# Train average loss: 0.03397059912568555
# [ Validation epoch: 2 ]
# Accuarcy: 68.35926034634576
# Average loss: 0.02697786600456092
# Model saved! (time elapsed: 31.749046325683594)
# [ Train epoch: 2 ]
# Train accuarcy: 61.37080795479562
# Train average loss: 0.03155570385119636
# [ Validation epoch: 3 ]
# Accuarcy: 70.94217786909304
# Average loss: 0.024809780553320056
# Model saved! (time elapsed: 44.48923659324646)
# [ Train epoch: 3 ]
# Train accuarcy: 63.278784765539
# Train average loss: 0.030279617845998995
# [ Validation epoch: 4 ]
# Accuarcy: 73.43704138538304
# Average loss: 0.023506423551944614
# Model saved! (time elapsed: 57.99913215637207)
# [ Train epoch: 4 ]
# Train accuarcy: 65.19409994863139
# Train average loss: 0.029121762661955944
# [ Validation epoch: 5 ]
# Accuarcy: 71.82271793366598
# Average loss: 0.023676066733470297
# Model saved! (time elapsed: 70.64371585845947)
# [ Train epoch: 5 ]
# Train accuarcy: 65.56101856608204
# Train average loss: 0.0286616496367247
# [ Validation epoch: 6 ]
# Accuarcy: 66.15791018491342
# Average loss: 0.027223395529750647
# Model saved! (time elapsed: 84.09619688987732)
# [ Train epoch: 6 ]
# Train accuarcy: 66.76451163132018
# Train average loss: 0.028000951919918183
# [ Validation epoch: 7 ]
# Accuarcy: 75.16877017904315
# Average loss: 0.02229701737906879
# Model saved! (time elapsed: 96.7528624534607)
# [ Train epoch: 7 ]
# Train accuarcy: 67.35891979159022
# Train average loss: 0.027592030499348368
# [ Validation epoch: 8 ]
# Accuarcy: 74.90460815967127
# Average loss: 0.02199070135064233
# Model saved! (time elapsed: 109.39295673370361)
# [ Train epoch: 8 ]
# Train accuarcy: 68.18081749467969
# Train average loss: 0.02706659062597891
# [ Validation epoch: 9 ]
# Accuarcy: 76.81244496624596
# Average loss: 0.02147174321523957
# Model saved! (time elapsed: 122.83015871047974)
# [ Train epoch: 9 ]
# Train accuarcy: 68.96602333602407
# Train average loss: 0.026335553464373742
# [ Validation epoch: 10 ]
# Accuarcy: 75.1981215145289
# Average loss: 0.021862284910444434
# Model saved! (time elapsed: 135.48278975486755)
# [ Train epoch: 10 ]
# Train accuarcy: 69.18617450649445
# Train average loss: 0.02614382071208821
# [ Validation epoch: 11 ]
# Accuarcy: 75.99060757264455
# Average loss: 0.021659524630758466
# Model saved! (time elapsed: 149.20562529563904)
# [ Train epoch: 11 ]
# Train accuarcy: 69.20085125119249
# Train average loss: 0.025930429345628718
# [ Validation epoch: 12 ]
# Accuarcy: 74.81655415321397
# Average loss: 0.022119769488117162
# Model saved! (time elapsed: 161.82242012023926)
# [ Train epoch: 12 ]
# Train accuarcy: 69.6118001027372
# Train average loss: 0.025944778430118085
# [ Validation epoch: 13 ]
# Accuarcy: 76.66568828881714
# Average loss: 0.02104593885585224
# Model saved! (time elapsed: 175.16347432136536)
# [ Train epoch: 13 ]
# Train accuarcy: 69.93468848609379
# Train average loss: 0.025616149117821178
# [ Validation epoch: 14 ]
# Accuarcy: 78.01584972116231
# Average loss: 0.019955473830352125
# Model saved! (time elapsed: 188.0248417854309)
# [ Train epoch: 14 ]
# Train accuarcy: 70.52175827401483
# Train average loss: 0.02522408776354298
# [ Validation epoch: 15 ]
# Accuarcy: 77.72233636630466
# Average loss: 0.020372053658049023
# Model saved! (time elapsed: 201.02139043807983)
# [ Train epoch: 15 ]
# Train accuarcy: 71.49776179643355
# Train average loss: 0.024498950582594412
# [ Validation epoch: 16 ]
# Accuarcy: 79.04314646316408
# Average loss: 0.01946788037806478
# Model saved! (time elapsed: 214.37144112586975)
# [ Train epoch: 16 ]
# Train accuarcy: 70.8446466573714
# Train average loss: 0.02473517704965294
# [ Validation epoch: 17 ]
# Accuarcy: 78.01584972116231
# Average loss: 0.019822108337072323
# Model saved! (time elapsed: 226.94682669639587)
# [ Train epoch: 17 ]
# Train accuarcy: 71.10148968958686
# Train average loss: 0.024763293602045454
# [ Validation epoch: 18 ]
# Accuarcy: 75.72644555327267
# Average loss: 0.021734961297878046
# Model saved! (time elapsed: 240.548504114151)
# [ Train epoch: 18 ]
# Train accuarcy: 71.12350480663389
# Train average loss: 0.024583865692201376
# [ Validation epoch: 19 ]
# Accuarcy: 78.7789844437922
# Average loss: 0.019648624255505343
# Model saved! (time elapsed: 253.22562551498413)
# [ Train epoch: 19 ]
# Train accuarcy: 71.76194320099802
# Train average loss: 0.02406708626611712
# [ Validation epoch: 20 ]
# Accuarcy: 78.33871441150572
# Average loss: 0.020013749643193687
# Model saved! (time elapsed: 267.4068877696991)
# [ Train epoch: 20 ]
# Train accuarcy: 71.67388273280986
# Train average loss: 0.024054999944879765
# [ Validation epoch: 21 ]
# Accuarcy: 77.75168770179043
# Average loss: 0.020384608597079433
# Model saved! (time elapsed: 280.97774720191956)
# [ Train epoch: 21 ]
# Train accuarcy: 71.9820943714684
# Train average loss: 0.024048044021160925
# [ Validation epoch: 22 ]
# Accuarcy: 76.95920164367479
# Average loss: 0.020694692100042607
# Model saved! (time elapsed: 293.7749092578888)
# [ Train epoch: 22 ]
# Train accuarcy: 72.57650253173846
# Train average loss: 0.023431084861476836
# [ Validation epoch: 23 ]
# Accuarcy: 78.86703845024948
# Average loss: 0.01926366534791526
# Model saved! (time elapsed: 307.5932581424713)
# [ Train epoch: 23 ]
# Train accuarcy: 71.9820943714684
# Train average loss: 0.02374987300602104
# [ Validation epoch: 24 ]
# Accuarcy: 79.83563252127972
# Average loss: 0.019085250582763585
# Model saved! (time elapsed: 320.5314972400665)
# [ Train epoch: 24 ]
# Train accuarcy: 72.70125486167169
# Train average loss: 0.023559792321977694
# [ Validation epoch: 25 ]
# Accuarcy: 81.0977399471676
# Average loss: 0.01816125187857745
# Model saved! (time elapsed: 333.82113814353943)
# [ Train epoch: 25 ]
# Train accuarcy: 72.92140603214207
# Train average loss: 0.022756320684699904
# [ Validation epoch: 26 ]
# Accuarcy: 78.36806574699149
# Average loss: 0.020815969825595713
# Model saved! (time elapsed: 346.6041007041931)
# [ Train epoch: 26 ]
# Train accuarcy: 73.40573860717693
# Train average loss: 0.022918476268989182
# [ Validation epoch: 27 ]
# Accuarcy: 79.13120046962136
# Average loss: 0.019256786793461635
# Model saved! (time elapsed: 359.33884739875793)
# [ Train epoch: 27 ]
# Train accuarcy: 73.01680487267924
# Train average loss: 0.022889973769195274
# [ Validation epoch: 28 ]
# Accuarcy: 79.45406515996478
# Average loss: 0.019842699445655067
# Model saved! (time elapsed: 373.1352963447571)
# [ Train epoch: 28 ]
# Train accuarcy: 73.03148161737727
# Train average loss: 0.02305225448518469
# [ Validation epoch: 29 ]
# Accuarcy: 78.6909304373349
# Average loss: 0.019560683213583282
# Model saved! (time elapsed: 385.95897364616394)
# [ Train epoch: 29 ]
# Train accuarcy: 73.24429441549864
# Train average loss: 0.023017576684813214
# [ Validation epoch: 30 ]
# Accuarcy: 78.74963310830643
# Average loss: 0.019763366039596348
# Model saved! (time elapsed: 399.5804328918457)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b>(알아보기) 혼동 행렬 시각화하기</b>
#
# * 참고: [Seaborn.heatmap 공식 문서](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# * 각 클래스에 대하여 정확히 분류하는지 확인하기 위해 <b>혼동 행렬(confusion matrix)</b>을 생성할 수 있습니다.

# %%
# 네트워크에 데이터셋을 입력하여 혼동 행렬(confusion matrix)을 계산하는 함수
def get_confusion_matrix(net, num_classes, data_loader):
    net.eval() # 모델을 평가 모드로 설정
    confusion_matrix = torch.zeros(num_classes, num_classes, dtype=torch.int32)

    for batch_idx, (inputs, targets) in enumerate(data_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs)
        _, predicted = outputs.max(1)

        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

    return confusion_matrix

# %%
import pandas as pd
import seaborn as sns


net = LeNet()
net = net.to(device)

file_name = "./checkpoint/LeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.8298, 0.9130, 0.7138, 0.7045, 0.7518, 0.8274])
# [ 전체 평균 정확도 ]
# tensor(0.7875)

# %% [markdown]
# #### <b>Problem 3. CustomLeNet 아키텍처 작성하기</b>
#
# * 다음과 같이 LeNet 아키텍처를 변경하여 CustomLeNet을 만들어 봅시다.
#     * 커널 크기와 커널의 개수를 증가시켰습니다. (파라미터 수 증가)
#     * Fully Connected 레이어의 차원을 증가시켰습니다. (파라미터 수 증가)
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 128, kernel size: 8 X 8, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 256, kernel size: 8 X 8, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Convolution | # of kernel: 512, kernel size: 4 X 4, stride: 1, zero padding: 0
# 7 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 8 | Fully Connected | # of neuron: 4096
# 9 | Activation | ReLU
# 10 | Fully Connected | # of neuron: 6
# 11 | Softmax | 6 classes

# %%
class CustomLeNet(nn.Module):
    def __init__(self):
        super(CustomLeNet, self).__init__()
        # 이 부분에 소스코드를 작성하세요.
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=128, kernel_size=8, stride=1, padding=0) # -> (128, 57, 57)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) # -> (128, 28, 28)
        self.conv2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=8, stride=1, padding=0) # -> (256, 21, 21)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) # -> (256, 10, 10)
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=1, padding=0) # -> (512, 7, 7)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) # -> (512, 3, 3)
        self.fc1 = nn.Linear(512 * 3 * 3, 4096)
        # → 차원(dimension): (500)
        self.fc2 = nn.Linear(4096, 6)
        # → 차원(dimension): (6)
    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = self.pool3(self.conv3(x))
        x = torch.flatten(x, 1) # 배치(batch)를 제외한 모든 차원 flatten하기
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# #### <b>(알아보기) CustomLeNet 평가하기</b>
#
# * 새롭게 작성한 CustomLeNet과 앞선 LeNet의 성능을 비교합니다.
#     * 파라미터가 증가한 만큼 성능 향상이 있는지 확인해 봅시다.
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.

# %%
import time
import torch.optim as optim


net = CustomLeNet()
net = net.to(device)

epoch = 40
learning_rate = 0.002
file_name = "CustomLeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 48.07367725838409
# Train average loss: 0.04102152566300228
# [ Validation epoch: 1 ]
# Accuarcy: 61.66715585559143
# Average loss: 0.03155767760180223
# Model saved! (time elapsed: 17.150172472000122)
# [ Train epoch: 1 ]
# Train accuarcy: 56.34402289572173
# Train average loss: 0.03513294282554049
# [ Validation epoch: 2 ]
# Accuarcy: 66.27531552685647
# Average loss: 0.028078484822131336
# Model saved! (time elapsed: 33.369722843170166)
# [ Train epoch: 2 ]
# Train accuarcy: 58.890438100829236
# Train average loss: 0.033241141657753354
# [ Validation epoch: 3 ]
# Accuarcy: 68.91693572057528
# Average loss: 0.027898836352799272
# Model saved! (time elapsed: 50.06408739089966)
# [ Train epoch: 3 ]
# Train accuarcy: 60.798414911572614
# Train average loss: 0.032208002448178195
# [ Validation epoch: 4 ]
# Accuarcy: 70.2377458174347
# Average loss: 0.02639651659789728
# Model saved! (time elapsed: 66.22034096717834)
# [ Train epoch: 4 ]
# Train accuarcy: 61.715711455199234
# Train average loss: 0.03139504604191933
# [ Validation epoch: 5 ]
# Accuarcy: 68.35926034634576
# Average loss: 0.02669324784255077
# Model saved! (time elapsed: 82.9896879196167)
# [ Train epoch: 5 ]
# Train accuarcy: 63.66771850003669
# Train average loss: 0.030140750885989543
# [ Validation epoch: 6 ]
# Accuarcy: 73.29028470795421
# Average loss: 0.024178071213776253
# Model saved! (time elapsed: 98.6775712966919)
# [ Train epoch: 6 ]
# Train accuarcy: 64.05665223453438
# Train average loss: 0.029904907107694383
# [ Validation epoch: 7 ]
# Accuarcy: 72.0575286175521
# Average loss: 0.02476363469681713
# Model saved! (time elapsed: 115.5165958404541)
# [ Train epoch: 7 ]
# Train accuarcy: 64.0126220004403
# Train average loss: 0.029384469105910947
# [ Validation epoch: 8 ]
# Accuarcy: 72.6445553272674
# Average loss: 0.02378310372936505
# Model saved! (time elapsed: 131.38972973823547)
# [ Train epoch: 8 ]
# Train accuarcy: 64.98128715051001
# Train average loss: 0.029235297978173664
# [ Validation epoch: 9 ]
# Accuarcy: 72.5565013208101
# Average loss: 0.023755426023025335
# Model saved! (time elapsed: 147.99551582336426)
# [ Train epoch: 9 ]
# Train accuarcy: 65.97196741762677
# Train average loss: 0.028447912441290614
# [ Validation epoch: 10 ]
# Accuarcy: 73.20223070149692
# Average loss: 0.023518479942820587
# Model saved! (time elapsed: 163.9691710472107)
# [ Train epoch: 10 ]
# Train accuarcy: 66.02333602406986
# Train average loss: 0.02859347662415186
# [ Validation epoch: 11 ]
# Accuarcy: 73.02612268858233
# Average loss: 0.024291543744336064
# Model saved! (time elapsed: 180.91825652122498)
# [ Train epoch: 11 ]
# Train accuarcy: 66.92595582299846
# Train average loss: 0.027709113888444156
# [ Validation epoch: 12 ]
# Accuarcy: 73.81860874669798
# Average loss: 0.023207830471274508
# Model saved! (time elapsed: 197.20208740234375)
# [ Train epoch: 12 ]
# Train accuarcy: 66.85257209950834
# Train average loss: 0.027564729949283242
# [ Validation epoch: 13 ]
# Accuarcy: 72.87936601115351
# Average loss: 0.024291888880946612
# Model saved! (time elapsed: 213.95142340660095)
# [ Train epoch: 13 ]
# Train accuarcy: 67.32956630219417
# Train average loss: 0.027681080604094688
# [ Validation epoch: 14 ]
# Accuarcy: 71.44115057235105
# Average loss: 0.025244501589119242
# Model saved! (time elapsed: 229.6625154018402)
# [ Train epoch: 14 ]
# Train accuarcy: 67.44698025977839
# Train average loss: 0.027116239444870256
# [ Validation epoch: 15 ]
# Accuarcy: 75.57968887584386
# Average loss: 0.021778609969939938
# Model saved! (time elapsed: 246.3227298259735)
# [ Train epoch: 15 ]
# Train accuarcy: 68.11477214353856
# Train average loss: 0.026802494121400906
# [ Validation epoch: 16 ]
# Accuarcy: 73.84796008218373
# Average loss: 0.023011463782568287
# Model saved! (time elapsed: 262.5925090312958)
# [ Train epoch: 16 ]
# Train accuarcy: 68.67982681441256
# Train average loss: 0.02649749702286491
# [ Validation epoch: 17 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.021910202671154035
# Model saved! (time elapsed: 279.08463525772095)
# [ Train epoch: 17 ]
# Train accuarcy: 68.81925588904382
# Train average loss: 0.026544738583058423
# [ Validation epoch: 18 ]
# Accuarcy: 75.66774288230114
# Average loss: 0.021828150710718072
# Model saved! (time elapsed: 295.1199414730072)
# [ Train epoch: 18 ]
# Train accuarcy: 68.58442797387539
# Train average loss: 0.02630736333237204
# [ Validation epoch: 19 ]
# Accuarcy: 75.3742295274435
# Average loss: 0.022461382234274973
# Model saved! (time elapsed: 311.5283839702606)
# [ Train epoch: 19 ]
# Train accuarcy: 69.30358846407867
# Train average loss: 0.025776014415395666
# [ Validation epoch: 20 ]
# Accuarcy: 73.70120340475492
# Average loss: 0.02289302881980943
# Model saved! (time elapsed: 327.4702353477478)
# [ Train epoch: 20 ]
# Train accuarcy: 69.6631687091803
# Train average loss: 0.025032753124969796
# [ Validation epoch: 21 ]
# Accuarcy: 75.90255356618727
# Average loss: 0.021782045888172976
# Model saved! (time elapsed: 343.8547623157501)
# [ Train epoch: 21 ]
# Train accuarcy: 69.494386145153
# Train average loss: 0.025760258380040705
# [ Validation epoch: 22 ]
# Accuarcy: 73.26093337246844
# Average loss: 0.02304427452125191
# Model saved! (time elapsed: 360.7099084854126)
# [ Train epoch: 22 ]
# Train accuarcy: 69.72921406032142
# Train average loss: 0.02547004239578594
# [ Validation epoch: 23 ]
# Accuarcy: 76.04931024361609
# Average loss: 0.021681257145545474
# Model saved! (time elapsed: 377.1902618408203)
# [ Train epoch: 23 ]
# Train accuarcy: 70.29426873119542
# Train average loss: 0.025180435153545195
# [ Validation epoch: 24 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.020845784674231035
# Model saved! (time elapsed: 393.3998086452484)
# [ Train epoch: 24 ]
# Train accuarcy: 70.94004549790857
# Train average loss: 0.02486074759866221
# [ Validation epoch: 25 ]
# Accuarcy: 75.57968887584386
# Average loss: 0.022230366247645704
# Model saved! (time elapsed: 410.4101049900055)
# [ Train epoch: 25 ]
# Train accuarcy: 70.53643501871285
# Train average loss: 0.025184619671234497
# [ Validation epoch: 26 ]
# Accuarcy: 76.1960669210449
# Average loss: 0.021842567975618357
# Model saved! (time elapsed: 426.69010949134827)
# [ Train epoch: 26 ]
# Train accuarcy: 70.69054083804212
# Train average loss: 0.02477300951562572
# [ Validation epoch: 27 ]
# Accuarcy: 78.10390372761961
# Average loss: 0.02046452981392799
# Model saved! (time elapsed: 443.2581624984741)
# [ Train epoch: 27 ]
# Train accuarcy: 70.21354663535628
# Train average loss: 0.025209255053430694
# [ Validation epoch: 28 ]
# Accuarcy: 75.52098620487232
# Average loss: 0.021483497366654686
# Model saved! (time elapsed: 459.46218395233154)
# [ Train epoch: 28 ]
# Train accuarcy: 70.41168268877963
# Train average loss: 0.024855037859043076
# [ Validation epoch: 29 ]
# Accuarcy: 76.95920164367479
# Average loss: 0.020142207187328447
# Model saved! (time elapsed: 476.17606234550476)
# [ Train epoch: 29 ]
# Train accuarcy: 70.99875247670067
# Train average loss: 0.02467362917623438
# [ Validation epoch: 30 ]
# Accuarcy: 77.25271499853244
# Average loss: 0.020709983796747263
# Model saved! (time elapsed: 492.69939970970154)
# [ Train epoch: 30 ]
# Train accuarcy: 70.2795919864974
# Train average loss: 0.0247664567707237
# [ Validation epoch: 31 ]
# Accuarcy: 76.87114763721749
# Average loss: 0.021227526479289438
# Model saved! (time elapsed: 509.42588448524475)
# [ Train epoch: 31 ]
# Train accuarcy: 71.25559550891612
# Train average loss: 0.024217264382988095
# [ Validation epoch: 32 ]
# Accuarcy: 77.89844437921926
# Average loss: 0.020416961874050725
# Model saved! (time elapsed: 526.463803768158)
# [ Train epoch: 32 ]
# Train accuarcy: 72.1508769354957
# Train average loss: 0.023832891774193298
# [ Validation epoch: 33 ]
# Accuarcy: 75.3742295274435
# Average loss: 0.023118157255744037
# Model saved! (time elapsed: 542.964593410492)
# [ Train epoch: 33 ]
# Train accuarcy: 71.43171644529244
# Train average loss: 0.024218153496905523
# [ Validation epoch: 34 ]
# Accuarcy: 78.04520105664808
# Average loss: 0.019940620202419167
# Model saved! (time elapsed: 559.8120243549347)
# [ Train epoch: 34 ]
# Train accuarcy: 71.88669553093123
# Train average loss: 0.02401558511490044
# [ Validation epoch: 35 ]
# Accuarcy: 77.13530965658937
# Average loss: 0.021059430481787822
# Model saved! (time elapsed: 576.0373451709747)
# [ Train epoch: 35 ]
# Train accuarcy: 72.11418507375065
# Train average loss: 0.023789061800245755
# [ Validation epoch: 36 ]
# Accuarcy: 79.51276783093631
# Average loss: 0.019183948867860554
# Model saved! (time elapsed: 592.79247879982)
# [ Train epoch: 36 ]
# Train accuarcy: 72.01878623321348
# Train average loss: 0.02364818903262104
# [ Validation epoch: 37 ]
# Accuarcy: 77.6929850308189
# Average loss: 0.020557523744701815
# Model saved! (time elapsed: 609.3800811767578)
# [ Train epoch: 37 ]
# Train accuarcy: 72.00410948851545
# Train average loss: 0.023784977368670916
# [ Validation epoch: 38 ]
# Accuarcy: 79.16055180510713
# Average loss: 0.020021794560125646
# Model saved! (time elapsed: 626.2255752086639)
# [ Train epoch: 38 ]
# Train accuarcy: 72.61319439348352
# Train average loss: 0.023339260271397395
# [ Validation epoch: 39 ]
# Accuarcy: 78.48547108893455
# Average loss: 0.019186773475468388
# Model saved! (time elapsed: 642.613519191742)
# [ Train epoch: 39 ]
# Train accuarcy: 72.4297350847582
# Train average loss: 0.023400142881834753
# [ Validation epoch: 40 ]
# Accuarcy: 79.92368652773702
# Average loss: 0.019205467150573127
# Model saved! (time elapsed: 659.2373061180115)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = CustomLeNet()
net = net.to(device)

file_name = "./checkpoint/CustomLeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7476, 0.9426, 0.7912, 0.7629, 0.7696, 0.7868])
# [ 전체 평균 정확도 ]
# tensor(0.7992)

# %% [markdown]
# #### <b>Problem 4. AlexNet 아키텍처 작성하기</b>
#
# * AlexNet은 CNN 기반의 분류 모델의 우수성을 전 세계에 알린 논문([NIPS 2012](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf))입니다.
#     * ImageNet 분류 대회(ILSVRC 2012)에서 압도적인 성능으로 우승(1위)을 차지했습니다.
#
# <hr>
#
# * LRN (Local Response Normalization)을 활용합니다.
#     * PyTorch에서 [nn.LocalResponseNorm()](https://pytorch.org/docs/stable/generated/torch.nn.LocalResponseNorm.html)을 이용해 구현할 수 있습니다.
#     * Local Response Normalization은 입력과 출력의 차원이 동일한 레이어입니다.
# * Dropout을 활용합니다.
#     * PyTorch에서 [nn.Dropout()](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)을 이용해 구현할 수 있습니다.
# * ReLU를 적극적으로 활용합니다.
#     * PyTorch에서 [nn.ReLU()](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)를 이용해 구현할 수 있습니다.
#
# <hr>
#
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현해 봅시다.
#     * 원본 논문에서 제안한 것과 완전히 동일한 아키텍처는 아니지만, 핵심 아이디어를 잘 포함하고 있습니다.
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 96, kernel size: 5 X 5, stride: 1, zero padding: 2
# 3 | Activation | ReLU
# 4 | Normalization | LRN (Local Response Normalization), size: 5
# 5 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 6 | Convolution | # of kernel: 256, kernel size: 5 X 5, stride: 1, zero padding: 2
# 7 | Activation | ReLU
# 8 | Normalization | LRN (Local Response Normalization), size: 5
# 9 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 10 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 11 | Activation | ReLU
# 12 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 13 | Activation | ReLU
# 14 | Convolution | # of kernel: 256, kernel size: 3 X 3, stride: 1, zero padding: 1
# 15 | Activation | ReLU
# 16 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 17 | Fully Connected | # of neuron: 4096
# 18 | Activation | ReLU
# 19 | Dropout | Probability: 0.5
# 20 | Fully Connected | # of neuron: 6
# 21 | Dropout | Probability: 0.5
# 22 | Softmax | 6 classes
#
# * 표와 동일하게 정상적으로 구현했다면, <b>83~85%가량의 정확도</b>를 얻을 수 있습니다.

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        self.convnet = nn.Sequential(
            # Input Channel (RGB: 3)
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=5, padding=2, stride=1), # 64 -> 64
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3, stride=2), # 64 -> 31
            
            nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, padding=2, stride=1), # 31 -> 31
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3, stride=2), # 31 -> 15
            
            nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, padding=1, stride=1), # 15 -> 15
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, padding=1, stride=1), # 15 -> 15
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1, stride=1), # 15 -> 15
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2), # 7
        )

        self.fclayer = nn.Sequential(
            nn.Linear(256 * 7 * 7, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 6),
        )

    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x = self.convnet(x)
        x = torch.flatten(x, 1)
        x = self.fclayer(x)
        return x

# %% [markdown]
# #### <b>(알아보기) AlexNet 평가하기</b>
#
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.
# * 83~85%가량의 정확도가 나오지 않는다면, 표와 동일하게 AlexNet 코드를 다시 작성했는지 확인해 주세요.

# %%
import time
import torch.optim as optim


net = AlexNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "AlexNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 31.555001100755852
# Train average loss: 0.05027114051168834
# [ Validation epoch: 1 ]
# Accuarcy: 47.78397417082477
# Average loss: 0.03723596247683392
# Model saved! (time elapsed: 24.289952516555786)
# [ Train epoch: 1 ]
# Train accuarcy: 48.16907609892126
# Train average loss: 0.03885657700105223
# [ Validation epoch: 2 ]
# Accuarcy: 59.87672439095979
# Average loss: 0.03061960369462242
# Model saved! (time elapsed: 49.12747144699097)
# [ Train epoch: 2 ]
# Train accuarcy: 53.06377045571292
# Train average loss: 0.036051756013661826
# [ Validation epoch: 3 ]
# Accuarcy: 60.25829175227473
# Average loss: 0.030877906782101564
# Model saved! (time elapsed: 73.60607743263245)
# [ Train epoch: 3 ]
# Train accuarcy: 57.05584501357599
# Train average loss: 0.033362179537499
# [ Validation epoch: 4 ]
# Accuarcy: 65.54153213971236
# Average loss: 0.027708460499472655
# Model saved! (time elapsed: 98.34883522987366)
# [ Train epoch: 4 ]
# Train accuarcy: 59.60959859103251
# Train average loss: 0.03187970592592978
# [ Validation epoch: 5 ]
# Accuarcy: 66.97974757851482
# Average loss: 0.027553472432846685
# Model saved! (time elapsed: 123.36460018157959)
# [ Train epoch: 5 ]
# Train accuarcy: 62.58163939238277
# Train average loss: 0.02999486550639536
# [ Validation epoch: 6 ]
# Accuarcy: 73.67185206926915
# Average loss: 0.023491343716774513
# Model saved! (time elapsed: 147.75461411476135)
# [ Train epoch: 6 ]
# Train accuarcy: 66.50766859910472
# Train average loss: 0.027765655759023518
# [ Validation epoch: 7 ]
# Accuarcy: 76.75374229527444
# Average loss: 0.021051963613570035
# Model saved! (time elapsed: 172.50593256950378)
# [ Train epoch: 7 ]
# Train accuarcy: 69.28157334703162
# Train average loss: 0.025555254623196556
# [ Validation epoch: 8 ]
# Accuarcy: 75.93190490167302
# Average loss: 0.02131638450464406
# Model saved! (time elapsed: 197.38873648643494)
# [ Train epoch: 8 ]
# Train accuarcy: 69.97871872018786
# Train average loss: 0.0254270489754554
# [ Validation epoch: 9 ]
# Accuarcy: 73.58379806281185
# Average loss: 0.02178661640277523
# Model saved! (time elapsed: 222.00979661941528)
# [ Train epoch: 9 ]
# Train accuarcy: 71.59316063697072
# Train average loss: 0.023813900162785787
# [ Validation epoch: 10 ]
# Accuarcy: 80.39330789550925
# Average loss: 0.017727351915566916
# Model saved! (time elapsed: 246.44868421554565)
# [ Train epoch: 10 ]
# Train accuarcy: 72.51779555294635
# Train average loss: 0.022977217772723102
# [ Validation epoch: 11 ]
# Accuarcy: 78.1919577340769
# Average loss: 0.018513138321511795
# Model saved! (time elapsed: 271.22190523147583)
# [ Train epoch: 11 ]
# Train accuarcy: 73.22961767080062
# Train average loss: 0.022610986482950984
# [ Validation epoch: 12 ]
# Accuarcy: 81.12709128265337
# Average loss: 0.01705732456147933
# Model saved! (time elapsed: 295.86847257614136)
# [ Train epoch: 12 ]
# Train accuarcy: 73.87539443751376
# Train average loss: 0.021904797153619166
# [ Validation epoch: 13 ]
# Accuarcy: 82.06633401819782
# Average loss: 0.016035483520787448
# Model saved! (time elapsed: 320.6330409049988)
# [ Train epoch: 13 ]
# Train accuarcy: 74.17626770382329
# Train average loss: 0.021566964454641083
# [ Validation epoch: 14 ]
# Accuarcy: 81.44995597299678
# Average loss: 0.01682524914471397
# Model saved! (time elapsed: 345.35611152648926)
# [ Train epoch: 14 ]
# Train accuarcy: 75.40177588610847
# Train average loss: 0.020979697731259093
# [ Validation epoch: 15 ]
# Accuarcy: 78.57352509539184
# Average loss: 0.019091586992122715
# Model saved! (time elapsed: 369.63378262519836)
# [ Train epoch: 15 ]
# Train accuarcy: 76.0989212592647
# Train average loss: 0.020333919302640557
# [ Validation epoch: 16 ]
# Accuarcy: 82.65336072791312
# Average loss: 0.015298408179784192
# Model saved! (time elapsed: 393.9299509525299)
# [ Train epoch: 16 ]
# Train accuarcy: 76.64196081309166
# Train average loss: 0.019969485572737398
# [ Validation epoch: 17 ]
# Accuarcy: 82.88817141179923
# Average loss: 0.015229030398284021
# Model saved! (time elapsed: 418.30891585350037)
# [ Train epoch: 17 ]
# Train accuarcy: 77.14830850517355
# Train average loss: 0.019507726219059603
# [ Validation epoch: 18 ]
# Accuarcy: 82.15438802465512
# Average loss: 0.016254018829265648
# Model saved! (time elapsed: 443.03497076034546)
# [ Train epoch: 18 ]
# Train accuarcy: 77.50788875027519
# Train average loss: 0.01942684863085546
# [ Validation epoch: 19 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.014548461266476492
# Model saved! (time elapsed: 467.2421405315399)
# [ Train epoch: 19 ]
# Train accuarcy: 77.5152271226242
# Train average loss: 0.019055453657342864
# [ Validation epoch: 20 ]
# Accuarcy: 82.53595538597006
# Average loss: 0.015022020217327558
# Model saved! (time elapsed: 491.5138783454895)
# [ Train epoch: 20 ]
# Train accuarcy: 78.09495853819622
# Train average loss: 0.0185632324941774
# [ Validation epoch: 21 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.013583427987771892
# Model saved! (time elapsed: 515.8049423694611)
# [ Train epoch: 21 ]
# Train accuarcy: 78.85814926249358
# Train average loss: 0.018196556001186477
# [ Validation epoch: 22 ]
# Accuarcy: 82.77076606985618
# Average loss: 0.014413690869675937
# Model saved! (time elapsed: 540.0677473545074)
# [ Train epoch: 22 ]
# Train accuarcy: 78.53526087913701
# Train average loss: 0.01832951821505459
# [ Validation epoch: 23 ]
# Accuarcy: 82.71206339888465
# Average loss: 0.015047732903560585
# Model saved! (time elapsed: 565.3957099914551)
# [ Train epoch: 23 ]
# Train accuarcy: 79.11499229470904
# Train average loss: 0.017837002824213095
# [ Validation epoch: 24 ]
# Accuarcy: 83.65130613442912
# Average loss: 0.014397611174025002
# Model saved! (time elapsed: 589.9169511795044)
# [ Train epoch: 24 ]
# Train accuarcy: 79.05628531591692
# Train average loss: 0.01769722913942535
# [ Validation epoch: 25 ]
# Accuarcy: 84.76665688288817
# Average loss: 0.013755608696653446
# Model saved! (time elapsed: 614.2048516273499)
# [ Train epoch: 25 ]
# Train accuarcy: 79.43788067806561
# Train average loss: 0.017269288601481296
# [ Validation epoch: 26 ]
# Accuarcy: 85.29498092163193
# Average loss: 0.013030175413769083
# Model saved! (time elapsed: 638.4788453578949)
# [ Train epoch: 26 ]
# Train accuarcy: 80.20107140236296
# Train average loss: 0.016659553680458763
# [ Validation epoch: 27 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.012799464723809849
# Model saved! (time elapsed: 662.6219546794891)
# [ Train epoch: 27 ]
# Train accuarcy: 80.29647024290013
# Train average loss: 0.016825814608468378
# [ Validation epoch: 28 ]
# Accuarcy: 84.64925154094512
# Average loss: 0.013732083454522563
# Model saved! (time elapsed: 687.0771894454956)
# [ Train epoch: 28 ]
# Train accuarcy: 80.29647024290013
# Train average loss: 0.016700008715809577
# [ Validation epoch: 29 ]
# Accuarcy: 84.913413560317
# Average loss: 0.013632015799947732
# Model saved! (time elapsed: 711.9022781848907)
# [ Train epoch: 29 ]
# Train accuarcy: 81.16973655243267
# Train average loss: 0.016508910242106444
# [ Validation epoch: 30 ]
# Accuarcy: 85.41238626357499
# Average loss: 0.013332224065847399
# Model saved! (time elapsed: 736.2707443237305)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = AlexNet()
net = net.to(device)

file_name = "./checkpoint/AlexNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.8642, 0.9519, 0.7290, 0.8047, 0.9161, 0.8731])
# [ 전체 평균 정확도 ]
# tensor(0.8541)

# %% [markdown]
# #### <b>(알아보기) LightResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 가벼운 ResNet을 PyTorch로 구현한 것은 다음과 같습니다.
#     * 원본 논문에서는 CIFAR-10을 위하여 해당 아키텍처를 제안했습니다.
# * 레이어의 깊이에 따라 다양한 버전이 있습니다.
#     * 다양한 버전: 20 레이어, 32 레이어, 44 레이어, 56 레이어, 110 레이어
#     * 일반적으로 더 깊은 레이어로 구성된 ResNet이 더 높은 정확도를 보입니다.

# %%
# ResNet을 위한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (stride 값이 2라면, 너비와 높이가 절반으로 감소)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (stride 값이 1이므로, 너비와 높이가 유지)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, padding=0, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# LightResNet 클래스 정의
class LightResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(LightResNet, self).__init__()
        self.in_planes = 16

        # 16개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def LightResNet20():
    return LightResNet(BasicBlock, [3, 3, 3])


def LightResNet32():
    return LightResNet(BasicBlock, [5, 5, 5])


def LightResNet44():
    return LightResNet(BasicBlock, [7, 7, 7])


def LightResNet56():
    return LightResNet(BasicBlock, [9, 9, 9])


def LightResNet110():
    return LightResNet(BasicBlock, [18, 18, 18])

# %% [markdown]
# #### <b>(알아보기) LightResNet-20 학습하기</b>
#
# * PyTorch로 구현된 LightResNet-20 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = LightResNet20()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet20.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
#
# Train accuarcy: 53.01974022161885
#
# Train average loss: 0.03658798258906635
#
# [ Validation epoch: 1 ]
#
# Accuarcy: 63.45758732022307
#
# Average loss: 0.030574279776898725
#
# Model saved! (time elapsed: 19.993167638778687)
#
# [ Train epoch: 1 ]
#
# Train accuarcy: 63.66771850003669
#
# Train average loss: 0.029534709604923538
#
# [ Validation epoch: 2 ]
#
# Accuarcy: 67.03845024948635
#
# Average loss: 0.025827307688164717
#
# Model saved! (time elapsed: 40.28438663482666)
#
# [ Train epoch: 2 ]
#
# Train accuarcy: 67.76986864313496
#
# Train average loss: 0.0266216344731722
#
# [ Validation epoch: 3 ]
#
# Accuarcy: 73.70120340475492
#
# Average loss: 0.022831622013641237
#
# Model saved! (time elapsed: 60.15869474411011)
#
# [ Train epoch: 3 ]
#
# Train accuarcy: 70.6758640933441
#
# Train average loss: 0.024680457755003635
#
# [ Validation epoch: 4 ]
#
# Accuarcy: 75.93190490167302
#
# Average loss: 0.020515482482372716
#
# Model saved! (time elapsed: 79.83708763122559)
#
# [ Train epoch: 4 ]
#
# Train accuarcy: 72.29030601012695
#
# Train average loss: 0.023249017844120003
#
# [ Validation epoch: 5 ]
#
# Accuarcy: 77.57557968887585
#
# Average loss: 0.019185035239925895
#
# Model saved! (time elapsed: 99.97389483451843)
#
# [ Train epoch: 5 ]
#
# Train accuarcy: 74.16892933147427
#
# Train average loss: 0.022260874958147506
#
# [ Validation epoch: 6 ]
#
# Accuarcy: 75.3742295274435
#
# Average loss: 0.021790163596424498
#
# Model saved! (time elapsed: 119.94107580184937)
#
# [ Train epoch: 6 ]
#
# Train accuarcy: 74.89542819402656
#
# Train average loss: 0.0211937020234739
#
# [ Validation epoch: 7 ]
#
# Accuarcy: 77.07660698561784
#
# Average loss: 0.020383046144504226
#
# Model saved! (time elapsed: 139.78413653373718)
#
# [ Train epoch: 7 ]
#
# Train accuarcy: 75.93747706758641
#
# Train average loss: 0.020499446658742763
#
# [ Validation epoch: 8 ]
#
# Accuarcy: 80.48136190196654
#
# Average loss: 0.017031917053826715
#
# Model saved! (time elapsed: 159.7928671836853)
#
# [ Train epoch: 8 ]
#
# Train accuarcy: 76.09158288691569
#
# Train average loss: 0.02039750095219275
#
# [ Validation epoch: 9 ]
#
# Accuarcy: 80.33460522453771
#
# Average loss: 0.017676464248900195
#
# Model saved! (time elapsed: 179.76213812828064)
#
# [ Train epoch: 9 ]
#
# Train accuarcy: 76.45850150436632
#
# Train average loss: 0.019642550044716905
#
# [ Validation epoch: 10 ]
#
# Accuarcy: 79.04314646316408
#
# Average loss: 0.019096186827941484
#
# Model saved! (time elapsed: 199.96541810035706)
#
# [ Train epoch: 10 ]
#
# Train accuarcy: 77.78674689953769
#
# Train average loss: 0.01888047907111352
#
# [ Validation epoch: 11 ]
#
# Accuarcy: 81.68476665688289
#
# Average loss: 0.0158892130095972
#
# Model saved! (time elapsed: 219.83479404449463)
#
# [ Train epoch: 11 ]
#
# Train accuarcy: 77.14830850517355
#
# Train average loss: 0.018931139329694518
#
# [ Validation epoch: 12 ]
#
# Accuarcy: 81.12709128265337
#
# Average loss: 0.015638272377238933
#
# Model saved! (time elapsed: 239.6151487827301)
#
# [ Train epoch: 12 ]
#
# Train accuarcy: 77.6840096866515
#
# Train average loss: 0.01861783301475122
#
# [ Validation epoch: 13 ]
#
# Accuarcy: 78.6028764308776
#
# Average loss: 0.01794909078125944
#
# Model saved! (time elapsed: 259.6872823238373)
#
# [ Train epoch: 13 ]
#
# Train accuarcy: 78.73339693256035
#
# Train average loss: 0.018025166278733296
#
# [ Validation epoch: 14 ]
#
# Accuarcy: 82.27179336659817
#
# Average loss: 0.015956796532962062
#
# Model saved! (time elapsed: 279.6278612613678)
#
# [ Train epoch: 14 ]
#
# Train accuarcy: 79.04894694356791
#
# Train average loss: 0.017716647261716637
#
# [ Validation epoch: 15 ]
#
# Accuarcy: 77.92779571470501
#
# Average loss: 0.01960221711914666
#
# Model saved! (time elapsed: 299.5592715740204)
#
# [ Train epoch: 15 ]
#
# Train accuarcy: 79.05628531591692
#
# Train average loss: 0.017523714353046737
#
# [ Validation epoch: 16 ]
#
# Accuarcy: 84.44379219254476
#
# Average loss: 0.01342614016068937
#
# Model saved! (time elapsed: 319.6192226409912)
#
# [ Train epoch: 16 ]
#
# Train accuarcy: 79.658031848536
#
# Train average loss: 0.017384021119439104
#
# [ Validation epoch: 17 ]
#
# Accuarcy: 82.30114470208395
#
# Average loss: 0.015027176207169292
#
# Model saved! (time elapsed: 339.7433891296387)
#
# [ Train epoch: 17 ]
#
# Train accuarcy: 80.28913187055112
#
# Train average loss: 0.01709930207152495
#
# [ Validation epoch: 18 ]
#
# Accuarcy: 81.56736131493983
#
# Average loss: 0.01607475248046519
#
# Model saved! (time elapsed: 359.62662982940674)
#
# [ Train epoch: 18 ]
#
# Train accuarcy: 80.24510163645704
#
# Train average loss: 0.016639526516533724
#
# [ Validation epoch: 19 ]
#
# Accuarcy: 85.29498092163193
#
# Average loss: 0.012681122903149255
#
# Model saved! (time elapsed: 379.5420022010803)
#
# [ Train epoch: 19 ]
#
# Train accuarcy: 80.64137374330373
#
# Train average loss: 0.016597621589560078
#
# [ Validation epoch: 20 ]
#
# Accuarcy: 84.70795421191664
#
# Average loss: 0.013544214280917562
#
# Model saved! (time elapsed: 399.78393363952637)
#
# [ Train epoch: 20 ]
#
# Train accuarcy: 80.70008072209583
#
# Train average loss: 0.016480772397029494
#
# [ Validation epoch: 21 ]
#
# Accuarcy: 85.35368359260346
#
# Average loss: 0.012547882663598325
#
# Model saved! (time elapsed: 419.66964530944824)
#
# [ Train epoch: 21 ]
#
# Train accuarcy: 80.97893887135834
#
# Train average loss: 0.016427739567843082
#
# [ Validation epoch: 22 ]
#
# Accuarcy: 86.29292632814793
#
# Average loss: 0.012840229798122554
#
# Model saved! (time elapsed: 439.4618110656738)
#
# [ Train epoch: 22 ]
#
# Train accuarcy: 81.00095398840537
#
# Train average loss: 0.016134905649568203
#
# [ Validation epoch: 23 ]
#
# Accuarcy: 85.11887290871735
#
# Average loss: 0.01376184731905573
#
# Model saved! (time elapsed: 459.46183586120605)
#
# [ Train epoch: 23 ]
#
# Train accuarcy: 80.64137374330373
#
# Train average loss: 0.01607880648902151
#
# [ Validation epoch: 24 ]
#
# Accuarcy: 85.94071030231875
#
# Average loss: 0.012772566266849939
#
# Model saved! (time elapsed: 479.55182790756226)
#
# [ Train epoch: 24 ]
#
# Train accuarcy: 81.16973655243267
#
# Train average loss: 0.016023559044600146
#
# [ Validation epoch: 25 ]
#
# Accuarcy: 86.05811564426182
#
# Average loss: 0.012411195451313356
#
# Model saved! (time elapsed: 499.59899616241455)
#
# [ Train epoch: 25 ]
#
# Train accuarcy: 81.10369120129155
#
# Train average loss: 0.015906095538659324
#
# [ Validation epoch: 26 ]
#
# Accuarcy: 85.38303492808923
#
# Average loss: 0.01308906079213361
#
# Model saved! (time elapsed: 519.4412457942963)
#
# [ Train epoch: 26 ]
#
# Train accuarcy: 81.66874587216556
#
# Train average loss: 0.015559769019242857
#
# [ Validation epoch: 27 ]
#
# Accuarcy: 85.44173759906076
#
# Average loss: 0.01315807427042105
#
# Model saved! (time elapsed: 539.1203610897064)
#
# [ Train epoch: 27 ]
#
# Train accuarcy: 81.66140749981655
#
# Train average loss: 0.015695662735589245
#
# [ Validation epoch: 28 ]
#
# Accuarcy: 86.58643968300558
#
# Average loss: 0.011623867109772184
#
# Model saved! (time elapsed: 559.1105070114136)
#
# [ Train epoch: 28 ]
#
# Train accuarcy: 82.00631100022015
#
# Train average loss: 0.015297892252959919
#
# [ Validation epoch: 29 ]
#
# Accuarcy: 85.44173759906076
#
# Average loss: 0.012552066119773178
#
# Model saved! (time elapsed: 579.0282180309296)
#
# [ Train epoch: 29 ]
#
# Train accuarcy: 82.12372495780436
#
# Train average loss: 0.01516019025604417
#
# [ Validation epoch: 30 ]
#
# Accuarcy: 86.29292632814793
#
# Average loss: 0.012265232469561795
#
# Model saved! (time elapsed: 598.7567026615143)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = LightResNet20()
net = net.to(device)

file_name = "./checkpoint/LightResNet20.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
#
# tensor([523, 540, 594, 599, 560, 591])
#
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
#
# tensor([0.8528, 0.9574, 0.7727, 0.8097, 0.9429, 0.8545])
#
# [ 전체 평균 정확도 ]
#
# tensor(0.8629)

# %% [markdown]
# #### <b>Problem 5. 다양한 레이어 깊이에 따라 LightResNet 학습하기</b>
#
# * Residual Block을 사용하는 경우 깊이가 깊어져도 좋은 성능을 내는 경향이 있습니다.
# * 다음의 LightResNet 모델들에 대하여 각각 학습을 진행한 뒤에, 검증 정확도(validation accuracy)를 쓰세요.
#     * LightResNet32: {답을 쓰세요.}
#     * LightResNet56: {답을 쓰세요.}
#     * LightResNet110: {답을 쓰세요.}
# * 레이어가 깊어짐에 따라서 성능이 좋아지나요? {답을 쓰세요.}
#     * 그 이유는: {답을 쓰세요.}

# %% [markdown]
# #### <b>(알아보기) ResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 기본적인 ResNet의 핵심 아이디어를 PyTorch로 구현한 것은 다음과 같습니다.
#     * LightResNet에 비하여 <b>커널의 개수(number of kernels)가 많은</b> 것을 확인할 수 있습니다.
#     * 따라서 ImageNet과 같은 큰 규모의 데이터셋에 대해서 사용하기에 적합합니다.
# * (참고) [PyTorch 공식 ResNet 소스 코드](https://github.com/pytorch/vision/blob/master/torchvision/models/resnet.py)

# %%
# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# #### <b>(알아보기) ResNet-18 학습하기</b>
#
# * PyTorch로 구현된 ResNet-18 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = ResNet18()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
#
# Train accuarcy: 54.634182138401705
#
# Train average loss: 0.03552350132220593
#
# [ Validation epoch: 1 ]
#
# Accuarcy: 64.04461402993836
#
# Average loss: 0.030625102927267008
#
# Model saved! (time elapsed: 56.392067432403564)
#
# [ Train epoch: 1 ]
#
# Train accuarcy: 66.28017905628532
#
# Train average loss: 0.027683555574666258
#
# [ Validation epoch: 2 ]
#
# Accuarcy: 76.22541825653067
#
# Average loss: 0.020909708783813402
#
# Model saved! (time elapsed: 112.09643793106079)
#
# [ Train epoch: 2 ]
#
# Train accuarcy: 70.65384897629706
#
# Train average loss: 0.024552799536580516
#
# [ Validation epoch: 3 ]
#
# Accuarcy: 75.72644555327267
#
# Average loss: 0.020803920747529105
#
# Model saved! (time elapsed: 168.0892436504364)
#
# [ Train epoch: 3 ]
#
# Train accuarcy: 73.06083510677331
#
# Train average loss: 0.022823793206008802
#
# [ Validation epoch: 4 ]
#
# Accuarcy: 75.2861755209862
#
# Average loss: 0.020782165577028867
#
# Model saved! (time elapsed: 224.10530710220337)
#
# [ Train epoch: 4 ]
#
# Train accuarcy: 75.04953401335584
#
# Train average loss: 0.02116022261676045
#
# [ Validation epoch: 5 ]
#
# Accuarcy: 80.33460522453771
#
# Average loss: 0.016757638259545637
#
# Model saved! (time elapsed: 280.1415412425995)
#
# [ Train epoch: 5 ]
#
# Train accuarcy: 76.37044103617818
#
# Train average loss: 0.01991496870949358
#
# [ Validation epoch: 6 ]
#
# Accuarcy: 81.5086586439683
#
# Average loss: 0.015801148935780693
#
# Model saved! (time elapsed: 336.057856798172)
#
# [ Train epoch: 6 ]
#
# Train accuarcy: 76.81074337711895
#
# Train average loss: 0.019498130532819895
#
# [ Validation epoch: 7 ]
#
# Accuarcy: 81.44995597299678
#
# Average loss: 0.015548953277504196
#
# Model saved! (time elapsed: 392.00325560569763)
#
# [ Train epoch: 7 ]
#
# Train accuarcy: 77.7940852718867
#
# Train average loss: 0.018866681710127262
#
# [ Validation epoch: 8 ]
#
# Accuarcy: 84.17963017317288
#
# Average loss: 0.013664885371319878
#
# Model saved! (time elapsed: 448.02228832244873)
#
# [ Train epoch: 8 ]
#
# Train accuarcy: 79.0416085712189
#
# Train average loss: 0.017912666459264467
#
# [ Validation epoch: 9 ]
#
# Accuarcy: 85.08952157323158
#
# Average loss: 0.013463371545120107
#
# Model saved! (time elapsed: 504.14816403388977)
#
# [ Train epoch: 9 ]
#
# Train accuarcy: 79.08563880531298
#
# Train average loss: 0.0176577540355776
#
# [ Validation epoch: 10 ]
#
# Accuarcy: 83.09363076019959
#
# Average loss: 0.015103666531154407
#
# Model saved! (time elapsed: 560.1805219650269)
#
# [ Train epoch: 10 ]
#
# Train accuarcy: 80.3918690834373
#
# Train average loss: 0.01709865421382611
#
# [ Validation epoch: 11 ]
#
# Accuarcy: 82.24244203111242
#
# Average loss: 0.015596012194239922
#
# Model saved! (time elapsed: 616.2508070468903)
#
# [ Train epoch: 11 ]
#
# Train accuarcy: 80.94224700961327
#
# Train average loss: 0.01624337270765143
#
# [ Validation epoch: 12 ]
#
# Accuarcy: 85.55914294100381
#
# Average loss: 0.012451799748788525
#
# Model saved! (time elapsed: 672.3249988555908)
#
# [ Train epoch: 12 ]
#
# Train accuarcy: 81.61003889337346
#
# Train average loss: 0.015776265370195816
#
# [ Validation epoch: 13 ]
#
# Accuarcy: 85.91135896683299
#
# Average loss: 0.012401989475001958
#
# Model saved! (time elapsed: 728.4691355228424)
#
# [ Train epoch: 13 ]
#
# Train accuarcy: 81.30182725471491
#
# Train average loss: 0.015962627105162816
#
# [ Validation epoch: 14 ]
#
# Accuarcy: 86.58643968300558
#
# Average loss: 0.012299993589612302
#
# Model saved! (time elapsed: 784.5571179389954)
#
# [ Train epoch: 14 ]
#
# Train accuarcy: 81.925588904381
#
# Train average loss: 0.015660236149407397
#
# [ Validation epoch: 15 ]
#
# Accuarcy: 83.29909010859994
#
# Average loss: 0.01429344191469333
#
# Model saved! (time elapsed: 840.6422958374023)
#
# [ Train epoch: 15 ]
#
# Train accuarcy: 82.18243193659646
#
# Train average loss: 0.015174747478929577
#
# [ Validation epoch: 16 ]
#
# Accuarcy: 85.76460228940417
#
# Average loss: 0.012752274200560796
#
# Model saved! (time elapsed: 896.5983777046204)
#
# [ Train epoch: 16 ]
#
# Train accuarcy: 82.51265869230205
#
# Train average loss: 0.014840699627874113
#
# [ Validation epoch: 17 ]
#
# Accuarcy: 84.35573818608746
#
# Average loss: 0.0133746397007166
#
# Model saved! (time elapsed: 952.5179381370544)
#
# [ Train epoch: 17 ]
#
# Train accuarcy: 83.03368312908196
#
# Train average loss: 0.014693979498942373
#
# [ Validation epoch: 18 ]
#
# Accuarcy: 87.17346639272087
#
# Average loss: 0.01141935535101097
#
# Model saved! (time elapsed: 1008.4966914653778)
#
# [ Train epoch: 18 ]
#
# Train accuarcy: 82.97497615028986
#
# Train average loss: 0.014324165126709977
#
# [ Validation epoch: 19 ]
#
# Accuarcy: 87.3202230701497
#
# Average loss: 0.011493727877530528
#
# Model saved! (time elapsed: 1064.543095111847)
#
# [ Train epoch: 19 ]
#
# Train accuarcy: 82.94562266089382
#
# Train average loss: 0.014492610786712956
#
# [ Validation epoch: 20 ]
#
# Accuarcy: 87.96595245083651
#
# Average loss: 0.010962819752190727
#
# Model saved! (time elapsed: 1120.5771708488464)
#
# [ Train epoch: 20 ]
#
# Train accuarcy: 83.36390988478756
#
# Train average loss: 0.014021456331274888
#
# [ Validation epoch: 21 ]
#
# Accuarcy: 87.6430877604931
#
# Average loss: 0.010934485408491427
#
# Model saved! (time elapsed: 1176.5525619983673)
#
# [ Train epoch: 21 ]
#
# Train accuarcy: 83.98767153445365
#
# Train average loss: 0.013677046207039006
#
# [ Validation epoch: 22 ]
#
# Accuarcy: 88.11270912826534
#
# Average loss: 0.011205443542200273
#
# Model saved! (time elapsed: 1232.49391579628)
#
# [ Train epoch: 22 ]
#
# Train accuarcy: 83.61341454465399
#
# Train average loss: 0.013903976396549611
#
# [ Validation epoch: 23 ]
#
# Accuarcy: 88.40622248312299
#
# Average loss: 0.010049392569002114
#
# Model saved! (time elapsed: 1288.4434094429016)
#
# [ Train epoch: 23 ]
#
# Train accuarcy: 84.22249944962208
#
# Train average loss: 0.01332762242435158
#
# [ Validation epoch: 24 ]
#
# Accuarcy: 88.17141179923686
#
# Average loss: 0.011050569360989925
#
# Model saved! (time elapsed: 1344.5159559249878)
#
# [ Train epoch: 24 ]
#
# Train accuarcy: 84.24451456666911
#
# Train average loss: 0.013455687868644987
#
# [ Validation epoch: 25 ]
#
# Accuarcy: 86.70384502494863
#
# Average loss: 0.012711640194797572
#
# Model saved! (time elapsed: 1400.5662755966187)
#
# [ Train epoch: 25 ]
#
# Train accuarcy: 85.05173552506054
#
# Train average loss: 0.013233664584932301
#
# [ Validation epoch: 26 ]
#
# Accuarcy: 88.08335779277957
#
# Average loss: 0.01063289316625304
#
# Model saved! (time elapsed: 1456.622546672821)
#
# [ Train epoch: 26 ]
#
# Train accuarcy: 84.67014016291186
#
# Train average loss: 0.012937242616961163
#
# [ Validation epoch: 27 ]
#
# Accuarcy: 88.05400645729381
#
# Average loss: 0.01054535748446341
#
# Model saved! (time elapsed: 1512.6548464298248)
#
# [ Train epoch: 27 ]
#
# Train accuarcy: 84.84626109928818
#
# Train average loss: 0.01287252098866479
#
# [ Validation epoch: 28 ]
#
# Accuarcy: 89.19870854123863
#
# Average loss: 0.010300897373450198
#
# Model saved! (time elapsed: 1568.5828454494476)
#
# [ Train epoch: 28 ]
#
# Train accuarcy: 85.04439715271153
#
# Train average loss: 0.012630687983490763
#
# [ Validation epoch: 29 ]
#
# Accuarcy: 88.52362782506604
#
# Average loss: 0.010554869175132223
#
# Model saved! (time elapsed: 1624.550882101059)
#
# [ Train epoch: 29 ]
#
# Train accuarcy: 85.56542158949145
#
# Train average loss: 0.012323715384860132
#
# [ Validation epoch: 30 ]
#
# Accuarcy: 87.26152039917817
#
# Average loss: 0.010899315978254711
#
# Model saved! (time elapsed: 1680.5771353244781)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = ResNet18()
net = net.to(device)

file_name = "./checkpoint/ResNet18.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
#
# tensor([523, 540, 594, 599, 560, 591])
#
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
#
# tensor([0.9446, 0.9667, 0.8114, 0.8564, 0.8946, 0.7800])
#
# [ 전체 평균 정확도 ]
#
# tensor(0.8726)

# %% [markdown]
# #### <b>(알아보기) Input Mixup 살펴보기</b>
#
# * Mixup은 대표적인 데이터 증진(data augmentation) 기법으로 정확도 향상에 도움이 됩니다.
#     * 일반적으로 Mixup을 사용하는 경우 더 많은 횟수(1.5배가량)의 epoch이 요구됩니다.

# %%
mixup_alpha = 1.0


def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


def train_with_mixup(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets) # Mixup 진행
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)

# %% [markdown]
# #### <b>Problem 6. Mixup 결과 분석하기</b>
#
# * Mixup을 사용하여 ResNet-18에 대하여 50번 epoch만큼 학습을 진행한 뒤에 성능이 얼마나 개선되었는지 쓰세요.
#     * Mixup을 적용했을 때의 검증 정확도(validation accuracy): {답을 쓰세요.}

# %%
import time
import torch.optim as optim

# ResNet을 위한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (stride 값이 2라면, 너비와 높이가 절반으로 감소)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (stride 값이 1이므로, 너비와 높이가 유지)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, padding=0, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out
    
net = ResNet18()
net = net.to(device)

epoch = 50
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 43.70505645372663
# Train average loss: 0.04535692718082035
# [ Validation epoch: 1 ]
# Accuarcy: 59.700616378045204
# Average loss: 0.03315880164254751
# Model saved! (time elapsed: 26.23692750930786)
# [ Train epoch: 1 ]
# Train accuarcy: 51.16308491976616
# Train average loss: 0.041053710491560855
# [ Validation epoch: 2 ]
# Accuarcy: 65.10126210742588
# Average loss: 0.03086219482629013
# Model saved! (time elapsed: 52.013530015945435)
# [ Train epoch: 2 ]
# Train accuarcy: 54.41785548785024
# Train average loss: 0.038893828429995225
# [ Validation epoch: 3 ]
# Accuarcy: 72.93806868212504
# Average loss: 0.024703810501560494
# Model saved! (time elapsed: 77.77787375450134)
# [ Train epoch: 3 ]
# Train accuarcy: 55.79548828919165
# Train average loss: 0.03805534814873226
# [ Validation epoch: 4 ]
# Accuarcy: 76.84179630173173
# Average loss: 0.02215869301814714
# Model saved! (time elapsed: 103.41778993606567)
# [ Train epoch: 4 ]
# Train accuarcy: 56.14948483793823
# Train average loss: 0.037697805367711446
# [ Validation epoch: 5 ]
# Accuarcy: 77.57557968887585
# Average loss: 0.020662194941797527
# Model saved! (time elapsed: 129.55887603759766)
# [ Train epoch: 5 ]
# Train accuarcy: 57.77165573862227
# Train average loss: 0.03656086812254145
# [ Validation epoch: 6 ]
# Accuarcy: 72.9674200176108
# Average loss: 0.023599753622649034
# Model saved! (time elapsed: 155.35078239440918)
# [ Train epoch: 6 ]
# Train accuarcy: 58.28962226559517
# Train average loss: 0.03608823937943547
# [ Validation epoch: 7 ]
# Accuarcy: 80.33460522453771
# Average loss: 0.019078174162582808
# Model saved! (time elapsed: 181.10177421569824)
# [ Train epoch: 7 ]
# Train accuarcy: 59.77959500011217
# Train average loss: 0.03548499946855979
# [ Validation epoch: 8 ]
# Accuarcy: 80.33460522453771
# Average loss: 0.01883914040651425
# Model saved! (time elapsed: 207.0654742717743)
# [ Train epoch: 8 ]
# Train accuarcy: 59.29613568829401
# Train average loss: 0.03541941037660581
# [ Validation epoch: 9 ]
# Accuarcy: 83.21103610214264
# Average loss: 0.01841085077661694
# Model saved! (time elapsed: 233.10495591163635)
# [ Train epoch: 9 ]
# Train accuarcy: 60.1482684636816
# Train average loss: 0.03487011514275494
# [ Validation epoch: 10 ]
# Accuarcy: 82.0076313472263
# Average loss: 0.018380332437469914
# Model saved! (time elapsed: 258.65329122543335)
# [ Train epoch: 10 ]
# Train accuarcy: 60.73347431332652
# Train average loss: 0.03457101989695215
# [ Validation epoch: 11 ]
# Accuarcy: 79.48341649545054
# Average loss: 0.019570261624890197
# Model saved! (time elapsed: 284.717143535614)
# [ Train epoch: 11 ]
# Train accuarcy: 61.5874832017125
# Train average loss: 0.033867021236239817
# [ Validation epoch: 12 ]
# Accuarcy: 84.32638685060171
# Average loss: 0.01614222820549722
# Model saved! (time elapsed: 310.7626574039459)
# [ Train epoch: 12 ]
# Train accuarcy: 60.782401511733106
# Train average loss: 0.03426280877748868
# [ Validation epoch: 13 ]
# Accuarcy: 84.64925154094512
# Average loss: 0.017171423719326073
# Model saved! (time elapsed: 336.72730708122253)
# [ Train epoch: 13 ]
# Train accuarcy: 60.84728098840469
# Train average loss: 0.03414398986183819
# [ Validation epoch: 14 ]
# Accuarcy: 84.913413560317
# Average loss: 0.017967856434177434
# Model saved! (time elapsed: 363.2802333831787)
# [ Train epoch: 14 ]
# Train accuarcy: 62.36379673464614
# Train average loss: 0.03315726230296191
# [ Validation epoch: 15 ]
# Accuarcy: 85.61784561197534
# Average loss: 0.015469371520216808
# Model saved! (time elapsed: 388.87884545326233)
# [ Train epoch: 15 ]
# Train accuarcy: 62.180055526092126
# Train average loss: 0.03347263810018227
# [ Validation epoch: 16 ]
# Accuarcy: 86.02876430877605
# Average loss: 0.014912827661529397
# Model saved! (time elapsed: 414.8634979724884)
# [ Train epoch: 16 ]
# Train accuarcy: 61.976334863030665
# Train average loss: 0.033433131560319115
# [ Validation epoch: 17 ]
# Accuarcy: 86.02876430877605
# Average loss: 0.01578570595751909
# Model saved! (time elapsed: 440.7726876735687)
# [ Train epoch: 17 ]
# Train accuarcy: 63.586134062023035
# Train average loss: 0.032523821660740464
# [ Validation epoch: 18 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.017085347010797513
# Model saved! (time elapsed: 466.71322441101074)
# [ Train epoch: 18 ]
# Train accuarcy: 63.33653611547828
# Train average loss: 0.032502313639383336
# [ Validation epoch: 19 ]
# Accuarcy: 85.73525095391841
# Average loss: 0.014964631318801094
# Model saved! (time elapsed: 492.58660340309143)
# [ Train epoch: 19 ]
# Train accuarcy: 63.028978887279976
# Train average loss: 0.03256095876178992
# [ Validation epoch: 20 ]
# Accuarcy: 81.91957734076901
# Average loss: 0.01747482212925713
# Model saved! (time elapsed: 518.115065574646)
# [ Train epoch: 20 ]
# Train accuarcy: 63.236595154389605
# Train average loss: 0.03258549296655597
# [ Validation epoch: 21 ]
# Accuarcy: 82.917522747285
# Average loss: 0.017162518064612546
# Model saved! (time elapsed: 543.9370791912079)
# [ Train epoch: 21 ]
# Train accuarcy: 63.97606338042561
# Train average loss: 0.03208092427169742
# [ Validation epoch: 22 ]
# Accuarcy: 85.11887290871735
# Average loss: 0.015973023805654674
# Model saved! (time elapsed: 569.7393350601196)
# [ Train epoch: 22 ]
# Train accuarcy: 64.29364335272795
# Train average loss: 0.03158120900762136
# [ Validation epoch: 23 ]
# Accuarcy: 87.90724977986498
# Average loss: 0.013640213841946901
# Model saved! (time elapsed: 595.6971883773804)
# [ Train epoch: 23 ]
# Train accuarcy: 63.60721110710805
# Train average loss: 0.03215612237422143
# [ Validation epoch: 24 ]
# Accuarcy: 87.17346639272087
# Average loss: 0.013608880872456321
# Model saved! (time elapsed: 621.5224010944366)
# [ Train epoch: 24 ]
# Train accuarcy: 64.51332904249523
# Train average loss: 0.03155760111773435
# [ Validation epoch: 25 ]
# Accuarcy: 83.44584678602877
# Average loss: 0.017169235186175164
# Model saved! (time elapsed: 647.2443976402283)
# [ Train epoch: 25 ]
# Train accuarcy: 63.67823582385139
# Train average loss: 0.031970863321902264
# [ Validation epoch: 26 ]
# Accuarcy: 84.29703551511594
# Average loss: 0.016819755081770738
# Model saved! (time elapsed: 673.078355550766)
# [ Train epoch: 26 ]
# Train accuarcy: 65.44630910005979
# Train average loss: 0.030974178010390197
# [ Validation epoch: 27 ]
# Accuarcy: 82.15438802465512
# Average loss: 0.01645843105159409
# Model saved! (time elapsed: 698.9059205055237)
# [ Train epoch: 27 ]
# Train accuarcy: 64.6785481849372
# Train average loss: 0.031331383233690786
# [ Validation epoch: 28 ]
# Accuarcy: 87.58438508952158
# Average loss: 0.013752582326360837
# Model saved! (time elapsed: 725.0748286247253)
# [ Train epoch: 28 ]
# Train accuarcy: 66.07730696799514
# Train average loss: 0.030239428739568024
# [ Validation epoch: 29 ]
# Accuarcy: 86.70384502494863
# Average loss: 0.013709401276092709
# Model saved! (time elapsed: 750.9319896697998)
# [ Train epoch: 29 ]
# Train accuarcy: 64.7278803610337
# Train average loss: 0.031146417824023713
# [ Validation epoch: 30 ]
# Accuarcy: 87.34957440563545
# Average loss: 0.013848381288106889
# Model saved! (time elapsed: 777.1104295253754)
# [ Train epoch: 30 ]
# Train accuarcy: 64.66193248784285
# Train average loss: 0.031211462574711267
# [ Validation epoch: 31 ]
# Accuarcy: 88.46492515409452
# Average loss: 0.012673893911173031
# Model saved! (time elapsed: 802.8405277729034)
# [ Train epoch: 31 ]
# Train accuarcy: 65.72631104027724
# Train average loss: 0.030504769836105814
# [ Validation epoch: 32 ]
# Accuarcy: 83.35779277957147
# Average loss: 0.016705318664328807
# Model saved! (time elapsed: 828.7387874126434)
# [ Train epoch: 32 ]
# Train accuarcy: 65.68692979995929
# Train average loss: 0.03028207736319051
# [ Validation epoch: 33 ]
# Accuarcy: 82.0076313472263
# Average loss: 0.01688769111578717
# Model saved! (time elapsed: 854.79847240448)
# [ Train epoch: 33 ]
# Train accuarcy: 65.76790552814867
# Train average loss: 0.030374471596001686
# [ Validation epoch: 34 ]
# Accuarcy: 85.8233049603757
# Average loss: 0.014091502812764566
# Model saved! (time elapsed: 881.2063457965851)
# [ Train epoch: 34 ]
# Train accuarcy: 65.52830902098756
# Train average loss: 0.030534886453037455
# [ Validation epoch: 35 ]
# Accuarcy: 87.84854710889346
# Average loss: 0.013737255425826874
# Model saved! (time elapsed: 907.365921497345)
# [ Train epoch: 35 ]
# Train accuarcy: 65.36729199121962
# Train average loss: 0.030766528488788896
# [ Validation epoch: 36 ]
# Accuarcy: 87.43762841209275
# Average loss: 0.014429247270835471
# Model saved! (time elapsed: 933.003820180893)
# [ Train epoch: 36 ]
# Train accuarcy: 64.37117838762252
# Train average loss: 0.031035213674025446
# [ Validation epoch: 37 ]
# Accuarcy: 88.02465512180804
# Average loss: 0.012983522025552844
# Model saved! (time elapsed: 959.2559168338776)
# [ Train epoch: 37 ]
# Train accuarcy: 66.05203885561302
# Train average loss: 0.029936826348505953
# [ Validation epoch: 38 ]
# Accuarcy: 87.05606105077781
# Average loss: 0.014840687488158987
# Model saved! (time elapsed: 985.2369866371155)
# [ Train epoch: 38 ]
# Train accuarcy: 65.6842775427528
# Train average loss: 0.030014405879007184
# [ Validation epoch: 39 ]
# Accuarcy: 85.17757557968888
# Average loss: 0.015057730777962733
# Model saved! (time elapsed: 1011.0897405147552)
# [ Train epoch: 39 ]
# Train accuarcy: 65.27226747357147
# Train average loss: 0.03050347547883848
# [ Validation epoch: 40 ]
# Accuarcy: 86.46903434106252
# Average loss: 0.014355946525752037
# Model saved! (time elapsed: 1037.1164779663086)
# [ Train epoch: 40 ]
# Train accuarcy: 66.90047832520123
# Train average loss: 0.029474990424489103
# [ Validation epoch: 41 ]
# Accuarcy: 88.52362782506604
# Average loss: 0.012864399680581862
# Model saved! (time elapsed: 1063.4015219211578)
# [ Train epoch: 41 ]
# Train accuarcy: 65.94456206391403
# Train average loss: 0.029913281502329685
# [ Validation epoch: 42 ]
# Accuarcy: 82.77076606985618
# Average loss: 0.016965725859624393
# Model saved! (time elapsed: 1089.06542634964)
# [ Train epoch: 42 ]
# Train accuarcy: 65.0074951641536
# Train average loss: 0.030427488070761823
# [ Validation epoch: 43 ]
# Accuarcy: 87.90724977986498
# Average loss: 0.01273504808864392
# Model saved! (time elapsed: 1114.829109430313)
# [ Train epoch: 43 ]
# Train accuarcy: 65.95083878589104
# Train average loss: 0.030021214150337934
# [ Validation epoch: 44 ]
# Accuarcy: 88.69973583798063
# Average loss: 0.01266505985376175
# Model saved! (time elapsed: 1140.5704836845398)
# [ Train epoch: 44 ]
# Train accuarcy: 66.84713039878267
# Train average loss: 0.02925157283681622
# [ Validation epoch: 45 ]
# Accuarcy: 87.3202230701497
# Average loss: 0.014655152863339311
# Model saved! (time elapsed: 1166.4903461933136)
# [ Train epoch: 45 ]
# Train accuarcy: 66.78628148383864
# Train average loss: 0.02926930296602135
# [ Validation epoch: 46 ]
# Accuarcy: 88.5529791605518
# Average loss: 0.012821170742783968
# Model saved! (time elapsed: 1192.4440093040466)
# [ Train epoch: 46 ]
# Train accuarcy: 66.47867827481228
# Train average loss: 0.029531506315631492
# [ Validation epoch: 47 ]
# Accuarcy: 87.52568241855005
# Average loss: 0.013552100319193365
# Model saved! (time elapsed: 1218.1181600093842)
# [ Train epoch: 47 ]
# Train accuarcy: 65.87913355444448
# Train average loss: 0.029798570179734567
# [ Validation epoch: 48 ]
# Accuarcy: 87.17346639272087
# Average loss: 0.013493869765293993
# Model saved! (time elapsed: 1243.9776022434235)
# [ Train epoch: 48 ]
# Train accuarcy: 66.99000985725839
# Train average loss: 0.02909553819289865
# [ Validation epoch: 49 ]
# Accuarcy: 88.11270912826534
# Average loss: 0.013863424222456034
# Model saved! (time elapsed: 1269.7866985797882)
# [ Train epoch: 49 ]
# Train accuarcy: 67.5818609254339
# Train average loss: 0.029114180513302036
# [ Validation epoch: 50 ]
# Accuarcy: 89.28676254769591
# Average loss: 0.0118150493512239
# Model saved! (time elapsed: 1295.5889847278595)

# %%
import pandas as pd
import seaborn as sns


net = ResNet18()
net = net.to(device)

file_name = "./checkpoint/ResNet18.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.9159, 0.9630, 0.8569, 0.8214, 0.9196, 0.8917])
# [ 전체 평균 정확도 ]
# tensor(0.8929)

# %% [markdown]
# #### <b>(알아보기) Transfer Learning 살펴보기</b>
#
# * 전이 학습(Transfer Learning)은 <b>단기간에 우수한 정확도</b>를 얻기 위해 효과적으로 사용할 수 있는 기법입니다.
#     * 본 실습에서는 미세 조정(fine-tuning) 기법을 사용합니다.
#     * 적은 epoch만으로도 빠르게 수렴합니다.
# * 전이 학습을 위해서는, 사전 학습된(pre-trained) 네트워크와 동일한 크기의 입력 차원을 갖도록 <b>데이터셋을 수정</b>해야 합니다.
#     * ResNet 특성상 데이터셋 수정 없이도 동작할 수 있지만, 일반적으로 데이터셋을 수정합니다.
# * (참고) [PyTorch 공식 Transfer Learning 튜토리얼](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
# * 기본적인 Transfer Learning을 이용해 91~93%의 정확도를 얻을 수 있습니다.

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
#
# Validation dataset size: 3407
#
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %%
net = torchvision.models.resnet18(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 20
learning_rate = 0.001 # 일반적으로 fine-tuning을 진행할 때는 학습률(learning rate)을 낮게 설정
file_name = "ResNet18Transferred.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
#
# Train accuarcy: 76.73735965362883
#
# Train average loss: 0.03927191147811609
#
# [ Validation epoch: 1 ]
#
# Accuarcy: 88.99324919283828
#
# Average loss: 0.01971462501815977
#
# Model saved! (time elapsed: 57.68897724151611)
#
# [ Train epoch: 1 ]
#
# Train accuarcy: 82.65208776693329
#
# Train average loss: 0.02987067018737882
#
# [ Validation epoch: 2 ]
#
# Accuarcy: 90.72497798649839
#
# Average loss: 0.016098890513715276
#
# Model saved! (time elapsed: 114.97562456130981)
#
# [ Train epoch: 2 ]
#
# Train accuarcy: 84.58207969472372
#
# Train average loss: 0.026206359815353027
#
# [ Validation epoch: 3 ]
#
# Accuarcy: 91.34135603169945
#
# Average loss: 0.01570589934555813
#
# Model saved! (time elapsed: 172.80669021606445)
#
# [ Train epoch: 3 ]
#
# Train accuarcy: 85.52139135539737
#
# Train average loss: 0.024795979192507644
#
# [ Validation epoch: 4 ]
#
# Accuarcy: 88.02465512180804
#
# Average loss: 0.022295160712753535
#
# Model saved! (time elapsed: 230.6609981060028)
#
# [ Train epoch: 4 ]
#
# Train accuarcy: 86.18184486680855
#
# Train average loss: 0.02377992051221562
#
# [ Validation epoch: 5 ]
#
# Accuarcy: 92.30995010272967
#
# Average loss: 0.014084740934960734
#
# Model saved! (time elapsed: 288.31283926963806)
#
# [ Train epoch: 5 ]
#
# Train accuarcy: 87.04043443164306
#
# Train average loss: 0.022508110433331393
#
# [ Validation epoch: 6 ]
#
# Accuarcy: 92.25124743175815
#
# Average loss: 0.01359202050597639
#
# Model saved! (time elapsed: 345.69286251068115)
#
# [ Train epoch: 6 ]
#
# Train accuarcy: 87.24590885741543
#
# Train average loss: 0.021195042326307187
#
# [ Validation epoch: 7 ]
#
# Accuarcy: 92.16319342530085
#
# Average loss: 0.014663816241332608
#
# Model saved! (time elapsed: 403.1283588409424)
#
# [ Train epoch: 7 ]
#
# Train accuarcy: 88.0824833052029
#
# Train average loss: 0.02046097561043436
#
# [ Validation epoch: 8 ]
#
# Accuarcy: 91.4587613736425
#
# Average loss: 0.015170558305997933
#
# Model saved! (time elapsed: 460.5742094516754)
#
# [ Train epoch: 8 ]
#
# Train accuarcy: 88.50077052909664
#
# Train average loss: 0.019577069311703655
#
# [ Validation epoch: 9 ]
#
# Accuarcy: 91.9577340769005
#
# Average loss: 0.014820666264320005
#
# Model saved! (time elapsed: 518.0491690635681)
#
# [ Train epoch: 9 ]
#
# Train accuarcy: 88.72092169956704
#
# Train average loss: 0.01915061301018335
#
# [ Validation epoch: 10 ]
#
# Accuarcy: 91.57616671558556
#
# Average loss: 0.015469911690453675
#
# Model saved! (time elapsed: 575.3326470851898)
#
# [ Train epoch: 10 ]
#
# Train accuarcy: 89.3226682321861
#
# Train average loss: 0.018218908906327425
#
# [ Validation epoch: 11 ]
#
# Accuarcy: 91.22395068975638
#
# Average loss: 0.016779066558510705
#
# Model saved! (time elapsed: 632.6658143997192)
#
# [ Train epoch: 11 ]
#
# Train accuarcy: 89.41806707272328
#
# Train average loss: 0.018030031635666213
#
# [ Validation epoch: 12 ]
#
# Accuarcy: 92.30995010272967
#
# Average loss: 0.0142230855012359
#
# Model saved! (time elapsed: 690.156346321106)
#
# [ Train epoch: 12 ]
#
# Train accuarcy: 89.57217289205255
#
# Train average loss: 0.017544450687229908
#
# [ Validation epoch: 13 ]
#
# Accuarcy: 91.5468153800998
#
# Average loss: 0.01602759961700895
#
# Model saved! (time elapsed: 747.4825925827026)
#
# [ Train epoch: 13 ]
#
# Train accuarcy: 89.81433917956997
#
# Train average loss: 0.017362345219721333
#
# [ Validation epoch: 14 ]
#
# Accuarcy: 92.42735544467273
#
# Average loss: 0.014935790816453727
#
# Model saved! (time elapsed: 804.6730387210846)
#
# [ Train epoch: 14 ]
#
# Train accuarcy: 90.18125779702062
#
# Train average loss: 0.016613503814373997
#
# [ Validation epoch: 15 ]
#
# Accuarcy: 92.01643674787204
#
# Average loss: 0.014743978859616718
#
# Model saved! (time elapsed: 861.9378566741943)
#
# [ Train epoch: 15 ]
#
# Train accuarcy: 90.54083804212226
#
# Train average loss: 0.016090837766955537
#
# [ Validation epoch: 16 ]
#
# Accuarcy: 91.98708541238626
#
# Average loss: 0.01607457565160516
#
# Model saved! (time elapsed: 919.4103908538818)
#
# [ Train epoch: 16 ]
#
# Train accuarcy: 90.46011594628311
#
# Train average loss: 0.01598841757304792
#
# [ Validation epoch: 17 ]
#
# Accuarcy: 92.51540945113003
#
# Average loss: 0.014857837464182034
#
# Model saved! (time elapsed: 976.765958070755)
#
# [ Train epoch: 17 ]
#
# Train accuarcy: 90.54083804212226
#
# Train average loss: 0.016162408172382778
#
# [ Validation epoch: 18 ]
#
# Accuarcy: 93.3665981802172
#
# Average loss: 0.013948299775530438
#
# Model saved! (time elapsed: 1034.075897693634)
#
# [ Train epoch: 18 ]
#
# Train accuarcy: 90.84171130843178
#
# Train average loss: 0.015477191083490795
#
# [ Validation epoch: 19 ]
#
# Accuarcy: 91.0478426768418
#
# Average loss: 0.017144537862419804
#
# Model saved! (time elapsed: 1091.335037469864)
#
# [ Train epoch: 19 ]
#
# Train accuarcy: 91.06186247890219
#
# Train average loss: 0.015025704684121562
#
# [ Validation epoch: 20 ]
#
# Accuarcy: 92.07513941884356
#
# Average loss: 0.016079544070838846
#
# Model saved! (time elapsed: 1148.6852900981903)

# %% [markdown]
# #### <b>Problem 7. State-of-the-Art 성능 만들기</b>
#
# * SOTA 수준의 성능을 만들어 보세요.
# * (참고) Transfer Learning과 Mixup을 함께 사용해 보세요.
#     * 더 큰 규모의 사전 학습된 모델(ResNet-50 이상)을 이용해 보세요.
# * (참고) learning rate scheduler를 사용해 보세요.
#
# <pre>
# def adjust_learning_rate(optimizer, epoch):
#     lr = learning_rate
#     if epoch >= 20:
#         lr /= 8
#     if epoch >= 40:
#         lr /= 8
#     for param_group in optimizer.param_groups:
#         param_group['lr'] = lr
# </pre>
#
# * 대회(competition)에 참여하고 있다고 생각하고, <b>94% 이상의 정확도</b>를 만들어 보세요.
#     * 내 모델의 검증 정확도(validation accuracy): {답을 쓰세요.}

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %%
net = torchvision.models.resnet152(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 50
learning_rate = 0.001 # 일반적으로 fine-tuning을 진행할 때는 학습률(learning rate)을 낮게 설정
file_name = "ResNet152TransferredMixup.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:02<00:00, 90.9MB/s]
# [ Train epoch: 0 ]
# Train accuarcy: 59.02582471741767
# Train average loss: 0.0727693681659357
# [ Validation epoch: 1 ]
# Accuarcy: 87.29087173466392
# Average loss: 0.02611636311156959
# Model saved! (time elapsed: 199.62545895576477)
# [ Train epoch: 1 ]
# Train accuarcy: 65.6481873943011
# Train average loss: 0.06374759591884603
# [ Validation epoch: 2 ]
# Accuarcy: 88.49427648958027
# Average loss: 0.025895094281947608
# Model saved! (time elapsed: 398.46998286247253)
# [ Train epoch: 2 ]
# Train accuarcy: 67.1820259853697
# Train average loss: 0.06106266274708177
# [ Validation epoch: 3 ]
# Accuarcy: 80.89228059876724
# Average loss: 0.05830853594024755
# Model saved! (time elapsed: 597.996105670929)
# [ Train epoch: 3 ]
# Train accuarcy: 67.31086696268513
# Train average loss: 0.060180326586792475
# [ Validation epoch: 4 ]
# Accuarcy: 90.63692398004109
# Average loss: 0.01943174972670989
# Model saved! (time elapsed: 797.3594064712524)
# [ Train epoch: 4 ]
# Train accuarcy: 67.75785309880511
# Train average loss: 0.05947160418690401
# [ Validation epoch: 5 ]
# Accuarcy: 91.40005870267098
# Average loss: 0.018733743422929584
# Model saved! (time elapsed: 996.3094637393951)
# [ Train epoch: 5 ]
# Train accuarcy: 68.03879031473667
# Train average loss: 0.05831658709943273
# [ Validation epoch: 6 ]
# Accuarcy: 92.48605811564425
# Average loss: 0.01758568059288934
# Model saved! (time elapsed: 1195.2310383319855)
# [ Train epoch: 6 ]
# Train accuarcy: 68.78943927319098
# Train average loss: 0.057127038865610096
# [ Validation epoch: 7 ]
# Accuarcy: 91.98708541238626
# Average loss: 0.018177457599913512
# Model saved! (time elapsed: 1395.351328611374)
# [ Train epoch: 7 ]
# Train accuarcy: 70.05089741713957
# Train average loss: 0.05528090599304583
# [ Validation epoch: 8 ]
# Accuarcy: 92.51540945113003
# Average loss: 0.017287425329459878
# Model saved! (time elapsed: 1594.4892945289612)
# [ Train epoch: 8 ]
# Train accuarcy: 69.73689598501186
# Train average loss: 0.055114818400522056
# [ Validation epoch: 9 ]
# Accuarcy: 92.5447607866158
# Average loss: 0.018131483342943563
# Model saved! (time elapsed: 1793.4406526088715)
# [ Train epoch: 9 ]
# Train accuarcy: 70.98297561660314
# Train average loss: 0.054022282487737064
# [ Validation epoch: 10 ]
# Accuarcy: 92.75022013501615
# Average loss: 0.016486675022834203
# Model saved! (time elapsed: 1993.1840770244598)
# [ Train epoch: 10 ]
# Train accuarcy: 68.98371170069662
# Train average loss: 0.05566073229441143
# [ Validation epoch: 11 ]
# Accuarcy: 92.63281479307308
# Average loss: 0.016361993662345992
# Model saved! (time elapsed: 2192.945901155472)
# [ Train epoch: 11 ]
# Train accuarcy: 70.12339315281146
# Train average loss: 0.0542705661002876
# [ Validation epoch: 12 ]
# Accuarcy: 92.10449075432932
# Average loss: 0.017188309278259328
# Model saved! (time elapsed: 2392.8010494709015)
# [ Train epoch: 12 ]
# Train accuarcy: 69.71535367802137
# Train average loss: 0.05417137731796421
# [ Validation epoch: 13 ]
# Accuarcy: 92.95567948341649
# Average loss: 0.01591250303687677
# Model saved! (time elapsed: 2592.3191318511963)
# [ Train epoch: 13 ]
# Train accuarcy: 70.79819512149612
# Train average loss: 0.05343067001734825
# [ Validation epoch: 14 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.016894462110274063
# Model saved! (time elapsed: 2791.656450986862)
# [ Train epoch: 14 ]
# Train accuarcy: 71.10684163654659
# Train average loss: 0.052302890075375454
# [ Validation epoch: 15 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.01546490529296788
# Model saved! (time elapsed: 2990.791652202606)
# [ Train epoch: 15 ]
# Train accuarcy: 71.18642435418548
# Train average loss: 0.052356853760757584
# [ Validation epoch: 16 ]
# Accuarcy: 93.24919283827414
# Average loss: 0.015734583089122123
# Model saved! (time elapsed: 3189.9147658348083)
# [ Train epoch: 16 ]
# Train accuarcy: 70.46393347515847
# Train average loss: 0.053266879224441295
# [ Validation epoch: 17 ]
# Accuarcy: 92.72086879953038
# Average loss: 0.01670264630705022
# Model saved! (time elapsed: 3388.752593278885)
# [ Train epoch: 17 ]
# Train accuarcy: 70.14573729571711
# Train average loss: 0.05359205494905381
# [ Validation epoch: 18 ]
# Accuarcy: 92.42735544467273
# Average loss: 0.017488918628839934
# Model saved! (time elapsed: 3588.1366159915924)
# [ Train epoch: 18 ]
# Train accuarcy: 70.56978682531897
# Train average loss: 0.0525894370120025
# [ Validation epoch: 19 ]
# Accuarcy: 93.24919283827414
# Average loss: 0.01580410954655354
# Model saved! (time elapsed: 3787.82363653183)
# [ Train epoch: 19 ]
# Train accuarcy: 70.56383743587227
# Train average loss: 0.05262841369677615
# [ Validation epoch: 20 ]
# Accuarcy: 92.51540945113003
# Average loss: 0.016820291447034147
# Model saved! (time elapsed: 3987.3118045330048)
# [ Train epoch: 20 ]
# Train accuarcy: 71.45457103440266
# Train average loss: 0.05136883852482192
# [ Validation epoch: 21 ]
# Accuarcy: 92.7795714705019
# Average loss: 0.016109019875447703
# Model saved! (time elapsed: 4186.712128400803)
# [ Train epoch: 21 ]
# Train accuarcy: 71.78228006412292
# Train average loss: 0.05072341631509382
# [ Validation epoch: 22 ]
# Accuarcy: 93.92427355444673
# Average loss: 0.01539390976998615
# Model saved! (time elapsed: 4386.22262263298)
# [ Train epoch: 22 ]
# Train accuarcy: 71.42449417670957
# Train average loss: 0.05125555131999117
# [ Validation epoch: 23 ]
# Accuarcy: 93.3665981802172
# Average loss: 0.015007658191036192
# Model saved! (time elapsed: 4585.391407012939)
# [ Train epoch: 23 ]
# Train accuarcy: 71.53231801195264
# Train average loss: 0.051120432085128176
# [ Validation epoch: 24 ]
# Accuarcy: 93.24919283827414
# Average loss: 0.014954106877294145
# Model saved! (time elapsed: 4783.743262767792)
# [ Train epoch: 24 ]
# Train accuarcy: 71.54066387318038
# Train average loss: 0.050994188273618755
# [ Validation epoch: 25 ]
# Accuarcy: 93.13178749633109
# Average loss: 0.016957933792261074
# Model saved! (time elapsed: 4983.145581960678)
# [ Train epoch: 25 ]
# Train accuarcy: 71.59441092456598
# Train average loss: 0.05071480527827454
# [ Validation epoch: 26 ]
# Accuarcy: 93.63076019958908
# Average loss: 0.01587237614951317
# Model saved! (time elapsed: 5181.749147891998)
# [ Train epoch: 26 ]
# Train accuarcy: 71.67896025740008
# Train average loss: 0.05039968065424869
# [ Validation epoch: 27 ]
# Accuarcy: 93.13178749633109
# Average loss: 0.01597984825319162
# Model saved! (time elapsed: 5380.376093387604)
# [ Train epoch: 27 ]
# Train accuarcy: 72.38410896806326
# Train average loss: 0.049966285709564254
# [ Validation epoch: 28 ]
# Accuarcy: 93.63076019958908
# Average loss: 0.015638115031561053
# Model saved! (time elapsed: 5579.088953971863)
# [ Train epoch: 28 ]
# Train accuarcy: 72.90099023720227
# Train average loss: 0.04960777941817031
# [ Validation epoch: 29 ]
# Accuarcy: 93.51335485764602
# Average loss: 0.014858236984140124
# Model saved! (time elapsed: 5778.897691011429)
# [ Train epoch: 29 ]
# Train accuarcy: 72.55150312316016
# Train average loss: 0.04966658498311923
# [ Validation epoch: 30 ]
# Accuarcy: 93.30789550924567
# Average loss: 0.016914024148688554
# Model saved! (time elapsed: 5977.84125328064)
# [ Train epoch: 30 ]
# Train accuarcy: 72.03404294307425
# Train average loss: 0.050199591761168304
# [ Validation epoch: 31 ]
# Accuarcy: 93.21984150278837
# Average loss: 0.01565053198723839
# Model saved! (time elapsed: 6177.1459884643555)
# [ Train epoch: 31 ]
# Train accuarcy: 72.504202957702
# Train average loss: 0.04934874126185865
# [ Validation epoch: 32 ]
# Accuarcy: 93.66011153507485
# Average loss: 0.015345473111436834
# Model saved! (time elapsed: 6376.9379715919495)
# [ Train epoch: 32 ]
# Train accuarcy: 72.90240918189973
# Train average loss: 0.049413995594365795
# [ Validation epoch: 33 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.016509900338092718
# Model saved! (time elapsed: 6576.25582075119)
# [ Train epoch: 33 ]
# Train accuarcy: 71.57787579158547
# Train average loss: 0.050436038686024205
# [ Validation epoch: 34 ]
# Accuarcy: 92.5447607866158
# Average loss: 0.017831817286820015
# Model saved! (time elapsed: 6775.286688089371)
# [ Train epoch: 34 ]
# Train accuarcy: 72.06892096466892
# Train average loss: 0.04980290620653035
# [ Validation epoch: 35 ]
# Accuarcy: 92.66216612855885
# Average loss: 0.01672947235757527
# Model saved! (time elapsed: 6974.673288106918)
# [ Train epoch: 35 ]
# Train accuarcy: 72.23400632274236
# Train average loss: 0.049256170573798455
# [ Validation epoch: 36 ]
# Accuarcy: 93.33724684473144
# Average loss: 0.01573000641855145
# Model saved! (time elapsed: 7174.167766332626)
# [ Train epoch: 36 ]
# Train accuarcy: 72.96739226189891
# Train average loss: 0.04860188717702833
# [ Validation epoch: 37 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.01633788263116339
# Model saved! (time elapsed: 7373.464871168137)
# [ Train epoch: 37 ]
# Train accuarcy: 73.23790153032469
# Train average loss: 0.04854252706023159
# [ Validation epoch: 38 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.01801830697460261
# Model saved! (time elapsed: 7573.044148921967)
# [ Train epoch: 38 ]
# Train accuarcy: 72.90597047632835
# Train average loss: 0.04886216058241277
# [ Validation epoch: 39 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.01616210588873185
# Model saved! (time elapsed: 7772.463353395462)
# [ Train epoch: 39 ]
# Train accuarcy: 72.4949269689682
# Train average loss: 0.04879249673583603
# [ Validation epoch: 40 ]
# Accuarcy: 93.13178749633109
# Average loss: 0.016222248730253255
# Model saved! (time elapsed: 7972.070389032364)
# [ Train epoch: 40 ]
# Train accuarcy: 72.81941973729178
# Train average loss: 0.04866174672056191
# [ Validation epoch: 41 ]
# Accuarcy: 93.80686821250367
# Average loss: 0.016049741095712118
# Model saved! (time elapsed: 8171.683751821518)
# [ Train epoch: 41 ]
# Train accuarcy: 73.5690516852043
# Train average loss: 0.04761825714823767
# [ Validation epoch: 42 ]
# Accuarcy: 93.4546521866745
# Average loss: 0.016473169971857736
# Model saved! (time elapsed: 8370.911514997482)
# [ Train epoch: 42 ]
# Train accuarcy: 73.21078283596188
# Train average loss: 0.04812118359560171
# [ Validation epoch: 43 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.0172765823313488
# Model saved! (time elapsed: 8570.494185447693)
# [ Train epoch: 43 ]
# Train accuarcy: 72.23962152498105
# Train average loss: 0.04909040855584565
# [ Validation epoch: 44 ]
# Accuarcy: 92.63281479307308
# Average loss: 0.01725900084620037
# Model saved! (time elapsed: 8771.089804410934)
# [ Train epoch: 44 ]
# Train accuarcy: 73.54606370863405
# Train average loss: 0.04758236292289552
# [ Validation epoch: 45 ]
# Accuarcy: 93.24919283827414
# Average loss: 0.01693731969993836
# Model saved! (time elapsed: 8970.951489686966)
# [ Train epoch: 45 ]
# Train accuarcy: 73.06632185363289
# Train average loss: 0.04810268361917759
# [ Validation epoch: 46 ]
# Accuarcy: 92.7795714705019
# Average loss: 0.01709420729941345
# Model saved! (time elapsed: 9171.078642845154)
# [ Train epoch: 46 ]
# Train accuarcy: 72.73148004389292
# Train average loss: 0.04851731346114905
# [ Validation epoch: 47 ]
# Accuarcy: 93.19049016730261
# Average loss: 0.015682704732508684
# Model saved! (time elapsed: 9370.607296228409)
# [ Train epoch: 47 ]
# Train accuarcy: 73.5343649134663
# Train average loss: 0.04756480324342262
# [ Validation epoch: 48 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.01693903901489872
# Model saved! (time elapsed: 9570.202357053757)
# [ Train epoch: 48 ]
# Train accuarcy: 73.85186918870613
# Train average loss: 0.046932349116683945
# [ Validation epoch: 49 ]
# Accuarcy: 93.39594951570297
# Average loss: 0.01641749132491292
# Model saved! (time elapsed: 9769.495176792145)
# [ Train epoch: 49 ]
# Train accuarcy: 73.14506742674206
# Train average loss: 0.04752125025206689
# [ Validation epoch: 50 ]
# Accuarcy: 93.3665981802172
# Average loss: 0.016105056280286075
# Model saved! (time elapsed: 9968.833712339401)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
net = torchvision.models.resnet152()
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

file_name = "./checkpoint/ResNet152TransferredMixup.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.5621, 0.7667, 0.6801, 0.6795, 0.9089, 0.0745])
# [ 전체 평균 정확도 ]
# tensor(0.6082)
